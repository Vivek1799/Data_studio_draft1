# %% [markdown]
# # In this notebook, I will try to make sense of the data I scraped from Westside Market for eggs, white bread and whole milk.

# %% [markdown]
# # Data Cleaning for eggs

# %%
import pandas as pd
df = pd.read_csv("eggs_at_westside.csv")

# %%
df
# Out:
#    prices                                        Egg_Product     Egg_size
# 0    $679                           JUST Egg plant-based egg     12 fl oz
# 1   $1089  Pete and Gerry’s Organic Eggs Eggs, Organic, F...        12 ct
# 2   $1349                    Eggland's Best Large White Eggs        18 ct
# 3    $679     Vital Farms Pasture Raised Large Eggs- 6 count         6 ct
# 4   $1119  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12 each
# 5   $1159  Happy Egg Medium Heirloom Fresh Free Range Blu...        12 ct
# 6    $559    Natures Yoke Legacy Free-Range Large Brown Eggs         6 ct
# 7   $1089  Pete and Gerry’s Organic Eggs Eggs, Organic, F...        12 ct
# 8    $729  Nature's Yoke Legacy Free Range Extra Large Br...        12 ct
# 9    $599          Thomas’ Light Multi-Grain English Muffins    6 x 13 oz
# 10   $789  The Country Hen Organic Grade A Eggs Extra- Large  6 x 13.5 oz
# 11   $589  Pete and Gerry’s Organic Eggs Eggs, Organic, F...         6 ct
# ...

# %%
df['prices'] = df['prices'].str.replace('$', '').astype(float) / 100
# Out:
# /var/folders/lc/wd3z5xrd5s7cbp_lm8v3mkdm0000gn/T/ipykernel_16379/379781824.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['prices'] = df['prices'].str.replace('$', '').astype(float) / 100

# %%
df['prices']
# Out:
# 0      6.79
# 1     10.89
# 2     13.49
# 3      6.79
# 4     11.19
# 5     11.59
# 6      5.59
# 7     10.89
# 8      7.29
# 9      5.99
# 10     7.89
# 11     5.89
# 12    10.09
# 13     9.99
# 14    10.89
# 15     6.79
# 16     7.29
# 17     7.19
# 18    11.19
# 19     9.99
# 20     5.59
# 21    11.79
# 22     7.89
# 23     7.19
# Name: prices, dtype: float64

# %%
df
# Out:
#     prices                                        Egg_Product     Egg_size
# 0     6.79                           JUST Egg plant-based egg     12 fl oz
# 1    10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...        12 ct
# 2    13.49                    Eggland's Best Large White Eggs        18 ct
# 3     6.79     Vital Farms Pasture Raised Large Eggs- 6 count         6 ct
# 4    11.19  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12 each
# 5    11.59  Happy Egg Medium Heirloom Fresh Free Range Blu...        12 ct
# 6     5.59    Natures Yoke Legacy Free-Range Large Brown Eggs         6 ct
# 7    10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...        12 ct
# 8     7.29  Nature's Yoke Legacy Free Range Extra Large Br...        12 ct
# 9     5.99          Thomas’ Light Multi-Grain English Muffins    6 x 13 oz
# 10    7.89  The Country Hen Organic Grade A Eggs Extra- Large  6 x 13.5 oz
# ...

# %%
df.dtypes
# Out:
# prices         float64
# Egg_Product     object
# Egg_size        object
# dtype: object

# %%
df['prices'] = df['prices'].apply(lambda x: '${:,.2f}'.format(x))

# %%
df
# Out:
#     prices                                        Egg_Product     Egg_size
# 0    $6.79                           JUST Egg plant-based egg     12 fl oz
# 1   $10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...        12 ct
# 2   $13.49                    Eggland's Best Large White Eggs        18 ct
# 3    $6.79     Vital Farms Pasture Raised Large Eggs- 6 count         6 ct
# 4   $11.19  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12 each
# 5   $11.59  Happy Egg Medium Heirloom Fresh Free Range Blu...        12 ct
# 6    $5.59    Natures Yoke Legacy Free-Range Large Brown Eggs         6 ct
# 7   $10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...        12 ct
# 8    $7.29  Nature's Yoke Legacy Free Range Extra Large Br...        12 ct
# 9    $5.99          Thomas’ Light Multi-Grain English Muffins    6 x 13 oz
# 10   $7.89  The Country Hen Organic Grade A Eggs Extra- Large  6 x 13.5 oz
# ...

# %%
df.drop(df.index[0], inplace=True)

# %%
df
# Out:
#     prices                                        Egg_Product     Egg_size
# 1   $10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...        12 ct
# 2   $13.49                    Eggland's Best Large White Eggs        18 ct
# 3    $6.79     Vital Farms Pasture Raised Large Eggs- 6 count         6 ct
# 4   $11.19  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12 each
# 5   $11.59  Happy Egg Medium Heirloom Fresh Free Range Blu...        12 ct
# 6    $5.59    Natures Yoke Legacy Free-Range Large Brown Eggs         6 ct
# 7   $10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...        12 ct
# 8    $7.29  Nature's Yoke Legacy Free Range Extra Large Br...        12 ct
# 9    $5.99          Thomas’ Light Multi-Grain English Muffins    6 x 13 oz
# 10   $7.89  The Country Hen Organic Grade A Eggs Extra- Large  6 x 13.5 oz
# 11   $5.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...         6 ct
# ...

# %%
mask = df["Egg_Product"].str.contains("Eggs", case=False)

# %%
mask
# Out:
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# Name: Egg_Product, dtype: bool

# %%
df.drop(df.index[9], inplace=True)

# %%
df
# Out:
#     prices                                        Egg_Product   Egg_size
# 1   $10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12 ct
# 2   $13.49                    Eggland's Best Large White Eggs      18 ct
# 3    $6.79     Vital Farms Pasture Raised Large Eggs- 6 count       6 ct
# 4   $11.19  Pete and Gerry’s Organic Eggs Eggs, Organic, F...    12 each
# 5   $11.59  Happy Egg Medium Heirloom Fresh Free Range Blu...      12 ct
# 6    $5.59    Natures Yoke Legacy Free-Range Large Brown Eggs       6 ct
# 7   $10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12 ct
# 8    $7.29  Nature's Yoke Legacy Free Range Extra Large Br...      12 ct
# 9    $5.99          Thomas’ Light Multi-Grain English Muffins  6 x 13 oz
# 12  $10.09  Nature's Yoke Organic Free-Range Large Brown Eggs      12 ct
# 13   $9.99  Nature's Yoke Free-Range Organic Large Brown Eggs      12 ct
# 14  $10.89        Nature's Yoke Free-Range Organic Jumbo Eggs      12 ct
# ...

# %%
mask
# Out:
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# Name: Egg_Product, dtype: bool

# %%
df = df[mask]
# Out:
# /var/folders/lc/wd3z5xrd5s7cbp_lm8v3mkdm0000gn/T/ipykernel_16379/1439040929.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = df[mask]

# %%
df
# Out:
#     prices                                        Egg_Product Egg_size
# 1   $10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...    12 ct
# 2   $13.49                    Eggland's Best Large White Eggs    18 ct
# 3    $6.79     Vital Farms Pasture Raised Large Eggs- 6 count     6 ct
# 4   $11.19  Pete and Gerry’s Organic Eggs Eggs, Organic, F...  12 each
# 5   $11.59  Happy Egg Medium Heirloom Fresh Free Range Blu...    12 ct
# 6    $5.59    Natures Yoke Legacy Free-Range Large Brown Eggs     6 ct
# 7   $10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...    12 ct
# 8    $7.29  Nature's Yoke Legacy Free Range Extra Large Br...    12 ct
# 12  $10.09  Nature's Yoke Organic Free-Range Large Brown Eggs    12 ct
# 13   $9.99  Nature's Yoke Free-Range Organic Large Brown Eggs    12 ct
# 14  $10.89        Nature's Yoke Free-Range Organic Jumbo Eggs    12 ct
# 15   $6.79  Pete and Gerry’s Organic Eggs Eggs, Organic, M...    12 ct
# ...

# %%
df['Egg_Product'].dtypes
# Out:
# dtype('O')

# %%
df
# Out:
#     prices                                        Egg_Product Egg_size
# 1   $10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...    12 ct
# 2   $13.49                    Eggland's Best Large White Eggs    18 ct
# 3    $6.79     Vital Farms Pasture Raised Large Eggs- 6 count     6 ct
# 4   $11.19  Pete and Gerry’s Organic Eggs Eggs, Organic, F...  12 each
# 5   $11.59  Happy Egg Medium Heirloom Fresh Free Range Blu...    12 ct
# 6    $5.59    Natures Yoke Legacy Free-Range Large Brown Eggs     6 ct
# 7   $10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...    12 ct
# 8    $7.29  Nature's Yoke Legacy Free Range Extra Large Br...    12 ct
# 12  $10.09  Nature's Yoke Organic Free-Range Large Brown Eggs    12 ct
# 13   $9.99  Nature's Yoke Free-Range Organic Large Brown Eggs    12 ct
# 14  $10.89        Nature's Yoke Free-Range Organic Jumbo Eggs    12 ct
# 15   $6.79  Pete and Gerry’s Organic Eggs Eggs, Organic, M...    12 ct
# ...

# %%
df
# Out:
#    prices                                        Egg_Product     Egg_size
# 0    $679                           JUST Egg plant-based egg     12 fl oz
# 1   $1089  Pete and Gerry’s Organic Eggs Eggs, Organic, F...        12 ct
# 2   $1349                    Eggland's Best Large White Eggs        18 ct
# 3    $679     Vital Farms Pasture Raised Large Eggs- 6 count         6 ct
# 4   $1119  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12 each
# 5   $1159  Happy Egg Medium Heirloom Fresh Free Range Blu...        12 ct
# 6    $559    Natures Yoke Legacy Free-Range Large Brown Eggs         6 ct
# 7   $1089  Pete and Gerry’s Organic Eggs Eggs, Organic, F...        12 ct
# 8    $729  Nature's Yoke Legacy Free Range Extra Large Br...        12 ct
# 9    $599          Thomas’ Light Multi-Grain English Muffins    6 x 13 oz
# 10   $789  The Country Hen Organic Grade A Eggs Extra- Large  6 x 13.5 oz
# 11   $589  Pete and Gerry’s Organic Eggs Eggs, Organic, F...         6 ct
# ...

# %%
df.drop(df.index[0], inplace=True)

# %%
df
# Out:
#    prices                                        Egg_Product     Egg_size
# 1   $1089  Pete and Gerry’s Organic Eggs Eggs, Organic, F...        12 ct
# 2   $1349                    Eggland's Best Large White Eggs        18 ct
# 3    $679     Vital Farms Pasture Raised Large Eggs- 6 count         6 ct
# 4   $1119  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12 each
# 5   $1159  Happy Egg Medium Heirloom Fresh Free Range Blu...        12 ct
# 6    $559    Natures Yoke Legacy Free-Range Large Brown Eggs         6 ct
# 7   $1089  Pete and Gerry’s Organic Eggs Eggs, Organic, F...        12 ct
# 8    $729  Nature's Yoke Legacy Free Range Extra Large Br...        12 ct
# 9    $599          Thomas’ Light Multi-Grain English Muffins    6 x 13 oz
# 10   $789  The Country Hen Organic Grade A Eggs Extra- Large  6 x 13.5 oz
# 11   $589  Pete and Gerry’s Organic Eggs Eggs, Organic, F...         6 ct
# 12  $1009  Nature's Yoke Organic Free-Range Large Brown Eggs        12 ct
# ...

# %%
df['prices'] = df['prices'].str.replace('$', '').astype(float) / 100
# Out:
# /var/folders/lc/wd3z5xrd5s7cbp_lm8v3mkdm0000gn/T/ipykernel_16379/379781824.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['prices'] = df['prices'].str.replace('$', '').astype(float) / 100

# %%
df['prices'] = df['prices'].apply(lambda x: '${:,.2f}'.format(x))

# %%
df
# Out:
#     prices                                        Egg_Product     Egg_size
# 1   $10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...        12 ct
# 2   $13.49                    Eggland's Best Large White Eggs        18 ct
# 3    $6.79     Vital Farms Pasture Raised Large Eggs- 6 count         6 ct
# 4   $11.19  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12 each
# 5   $11.59  Happy Egg Medium Heirloom Fresh Free Range Blu...        12 ct
# 6    $5.59    Natures Yoke Legacy Free-Range Large Brown Eggs         6 ct
# 7   $10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...        12 ct
# 8    $7.29  Nature's Yoke Legacy Free Range Extra Large Br...        12 ct
# 9    $5.99          Thomas’ Light Multi-Grain English Muffins    6 x 13 oz
# 10   $7.89  The Country Hen Organic Grade A Eggs Extra- Large  6 x 13.5 oz
# 11   $5.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...         6 ct
# ...

# %%
mask = df["Egg_Product"].str.contains("Eggs", case=False)
df = df[mask]

# %%
df
# Out:
#     prices                                        Egg_Product     Egg_size
# 1   $10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...        12 ct
# 2   $13.49                    Eggland's Best Large White Eggs        18 ct
# 3    $6.79     Vital Farms Pasture Raised Large Eggs- 6 count         6 ct
# 4   $11.19  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12 each
# 5   $11.59  Happy Egg Medium Heirloom Fresh Free Range Blu...        12 ct
# 6    $5.59    Natures Yoke Legacy Free-Range Large Brown Eggs         6 ct
# 7   $10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...        12 ct
# 8    $7.29  Nature's Yoke Legacy Free Range Extra Large Br...        12 ct
# 10   $7.89  The Country Hen Organic Grade A Eggs Extra- Large  6 x 13.5 oz
# 11   $5.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...         6 ct
# 12  $10.09  Nature's Yoke Organic Free-Range Large Brown Eggs        12 ct
# ...

# %%
df['Egg_size'] = df['Egg_size'].replace('6 x 13.5 oz', '6 ct')
# Out:
# /var/folders/lc/wd3z5xrd5s7cbp_lm8v3mkdm0000gn/T/ipykernel_16379/444874835.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Egg_size'] = df['Egg_size'].replace('6 x 13.5 oz', '6 ct')

# %%
df
# Out:
#     prices                                        Egg_Product Egg_size
# 1   $10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...    12 ct
# 2   $13.49                    Eggland's Best Large White Eggs    18 ct
# 3    $6.79     Vital Farms Pasture Raised Large Eggs- 6 count     6 ct
# 4   $11.19  Pete and Gerry’s Organic Eggs Eggs, Organic, F...  12 each
# 5   $11.59  Happy Egg Medium Heirloom Fresh Free Range Blu...    12 ct
# 6    $5.59    Natures Yoke Legacy Free-Range Large Brown Eggs     6 ct
# 7   $10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...    12 ct
# 8    $7.29  Nature's Yoke Legacy Free Range Extra Large Br...    12 ct
# 10   $7.89  The Country Hen Organic Grade A Eggs Extra- Large     6 ct
# 11   $5.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...     6 ct
# 12  $10.09  Nature's Yoke Organic Free-Range Large Brown Eggs    12 ct
# 13   $9.99  Nature's Yoke Free-Range Organic Large Brown Eggs    12 ct
# ...

# %%
df['Egg_size'] = df['Egg_size'].replace('12 each', '12 ct')
# Out:
# /var/folders/lc/wd3z5xrd5s7cbp_lm8v3mkdm0000gn/T/ipykernel_16379/3247574756.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Egg_size'] = df['Egg_size'].replace('12 each', '12 ct')

# %%
df
# Out:
#     prices                                        Egg_Product Egg_size
# 1   $10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...    12 ct
# 2   $13.49                    Eggland's Best Large White Eggs    18 ct
# 3    $6.79     Vital Farms Pasture Raised Large Eggs- 6 count     6 ct
# 4   $11.19  Pete and Gerry’s Organic Eggs Eggs, Organic, F...    12 ct
# 5   $11.59  Happy Egg Medium Heirloom Fresh Free Range Blu...    12 ct
# 6    $5.59    Natures Yoke Legacy Free-Range Large Brown Eggs     6 ct
# 7   $10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...    12 ct
# 8    $7.29  Nature's Yoke Legacy Free Range Extra Large Br...    12 ct
# 10   $7.89  The Country Hen Organic Grade A Eggs Extra- Large     6 ct
# 11   $5.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...     6 ct
# 12  $10.09  Nature's Yoke Organic Free-Range Large Brown Eggs    12 ct
# 13   $9.99  Nature's Yoke Free-Range Organic Large Brown Eggs    12 ct
# ...

# %%
df_sorted = df.sort_values('prices')

# %%
df_sorted
# Out:
#     prices                                        Egg_Product Egg_size
# 12  $10.09  Nature's Yoke Organic Free-Range Large Brown Eggs    12 ct
# 14  $10.89        Nature's Yoke Free-Range Organic Jumbo Eggs    12 ct
# 7   $10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...    12 ct
# 1   $10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...    12 ct
# 18  $11.19  Pete & Gerry's Organic Eggs Extra Large Brown ...    12 ct
# 4   $11.19  Pete and Gerry’s Organic Eggs Eggs, Organic, F...    12 ct
# 5   $11.59  Happy Egg Medium Heirloom Fresh Free Range Blu...    12 ct
# 21  $11.79          Sunshine Grade A Organic Large Brown Eggs    12 ct
# 2   $13.49                    Eggland's Best Large White Eggs    18 ct
# 20   $5.59  Nature's Yoke Organic Free-Range Large Brown Eggs     6 ct
# 6    $5.59    Natures Yoke Legacy Free-Range Large Brown Eggs     6 ct
# 11   $5.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...     6 ct
# ...

# %%
df
# Out:
#     prices                                        Egg_Product Egg_size
# 1   $10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...    12 ct
# 2   $13.49                    Eggland's Best Large White Eggs    18 ct
# 3    $6.79     Vital Farms Pasture Raised Large Eggs- 6 count     6 ct
# 4   $11.19  Pete and Gerry’s Organic Eggs Eggs, Organic, F...    12 ct
# 5   $11.59  Happy Egg Medium Heirloom Fresh Free Range Blu...    12 ct
# 6    $5.59    Natures Yoke Legacy Free-Range Large Brown Eggs     6 ct
# 7   $10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...    12 ct
# 8    $7.29  Nature's Yoke Legacy Free Range Extra Large Br...    12 ct
# 10   $7.89  The Country Hen Organic Grade A Eggs Extra- Large     6 ct
# 11   $5.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...     6 ct
# 12  $10.09  Nature's Yoke Organic Free-Range Large Brown Eggs    12 ct
# 13   $9.99  Nature's Yoke Free-Range Organic Large Brown Eggs    12 ct
# ...

# %%
df.dtypes
# Out:
# prices         object
# Egg_Product    object
# Egg_size       object
# dtype: object

# %%
df['prices'] = df['prices'].str.replace('$', '').astype(float)
df['Egg_size'] = df['Egg_size'].str.replace('ct', '').astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [52], line 1
# ----> 1 df['prices'] = df['prices'].str.replace('$', '').astype(float)
#       2 df['Egg_size'] = df['Egg_size'].str.replace('ct', '').astype(float)
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/pandas/core/accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
# ...

# %%
df
# Out:
#     prices                                        Egg_Product Egg_size
# 1    10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...    12 ct
# 2    13.49                    Eggland's Best Large White Eggs    18 ct
# 3     6.79     Vital Farms Pasture Raised Large Eggs- 6 count     6 ct
# 4    11.19  Pete and Gerry’s Organic Eggs Eggs, Organic, F...    12 ct
# 5    11.59  Happy Egg Medium Heirloom Fresh Free Range Blu...    12 ct
# 6     5.59    Natures Yoke Legacy Free-Range Large Brown Eggs     6 ct
# 7    10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...    12 ct
# 8     7.29  Nature's Yoke Legacy Free Range Extra Large Br...    12 ct
# 10    7.89  The Country Hen Organic Grade A Eggs Extra- Large     6 ct
# 11    5.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...     6 ct
# 12   10.09  Nature's Yoke Organic Free-Range Large Brown Eggs    12 ct
# 13    9.99  Nature's Yoke Free-Range Organic Large Brown Eggs    12 ct
# ...

# %%
df['prices'].dtypes
# Out:
# dtype('float64')

# %%
df['Egg_size'] = df['Egg_size'].str.replace('ct', '').astype(float)
# Out:
# /var/folders/lc/wd3z5xrd5s7cbp_lm8v3mkdm0000gn/T/ipykernel_16379/614683949.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Egg_size'] = df['Egg_size'].str.replace('ct', '').astype(float)

# %%
df
# Out:
#     prices                                        Egg_Product  Egg_size
# 1    10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12.0
# 2    13.49                    Eggland's Best Large White Eggs      18.0
# 3     6.79     Vital Farms Pasture Raised Large Eggs- 6 count       6.0
# 4    11.19  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12.0
# 5    11.59  Happy Egg Medium Heirloom Fresh Free Range Blu...      12.0
# 6     5.59    Natures Yoke Legacy Free-Range Large Brown Eggs       6.0
# 7    10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12.0
# 8     7.29  Nature's Yoke Legacy Free Range Extra Large Br...      12.0
# 10    7.89  The Country Hen Organic Grade A Eggs Extra- Large       6.0
# 11    5.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...       6.0
# 12   10.09  Nature's Yoke Organic Free-Range Large Brown Eggs      12.0
# 13    9.99  Nature's Yoke Free-Range Organic Large Brown Eggs      12.0
# ...

# %%
df_sorted = df.sort_values('prices')

# %%
df_sorted
# Out:
#     prices                                        Egg_Product  Egg_size
# 20    5.59  Nature's Yoke Organic Free-Range Large Brown Eggs       6.0
# 6     5.59    Natures Yoke Legacy Free-Range Large Brown Eggs       6.0
# 11    5.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...       6.0
# 3     6.79     Vital Farms Pasture Raised Large Eggs- 6 count       6.0
# 15    6.79  Pete and Gerry’s Organic Eggs Eggs, Organic, M...      12.0
# 23    7.19   Nature's Yoke Legacy Free Range Large Brown Eggs      12.0
# 17    7.19   Nature's Yoke Legacy Free-Range Large White Eggs      12.0
# 16    7.29         The Country Hen Organic Large Grade A Eggs       6.0
# 8     7.29  Nature's Yoke Legacy Free Range Extra Large Br...      12.0
# 10    7.89  The Country Hen Organic Grade A Eggs Extra- Large       6.0
# 22    7.89          Nature's Yoke Free-Range Jumbo Brown Eggs      12.0
# 19    9.99  Nature's Yoke Organic Free-Range Extra Large B...      12.0
# ...

# %%
df_new_sorted = df_sorted.reset_index(drop=True)

# %%
df_new_sorted
# Out:
#     prices                                        Egg_Product  Egg_size
# 0     5.59  Nature's Yoke Organic Free-Range Large Brown Eggs       6.0
# 1     5.59    Natures Yoke Legacy Free-Range Large Brown Eggs       6.0
# 2     5.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...       6.0
# 3     6.79     Vital Farms Pasture Raised Large Eggs- 6 count       6.0
# 4     6.79  Pete and Gerry’s Organic Eggs Eggs, Organic, M...      12.0
# 5     7.19   Nature's Yoke Legacy Free Range Large Brown Eggs      12.0
# 6     7.19   Nature's Yoke Legacy Free-Range Large White Eggs      12.0
# 7     7.29         The Country Hen Organic Large Grade A Eggs       6.0
# 8     7.29  Nature's Yoke Legacy Free Range Extra Large Br...      12.0
# 9     7.89  The Country Hen Organic Grade A Eggs Extra- Large       6.0
# 10    7.89          Nature's Yoke Free-Range Jumbo Brown Eggs      12.0
# 11    9.99  Nature's Yoke Organic Free-Range Extra Large B...      12.0
# ...

# %%
pd.options.display.max_colwidth = 100

# %%
df_new_sorted
# Out:
#     prices  \
# 0     5.59
# 1     5.59
# 2     5.89
# 3     6.79
# 4     6.79
# 5     7.19
# 6     7.19
# 7     7.29
# 8     7.29
# 9     7.89
# 10    7.89
# 11    9.99
# 12    9.99
# 13   10.09
# 14   10.89
# 15   10.89
# 16   10.89
# 17   11.19
# 18   11.19
# 19   11.59
# 20   11.79
# 21   13.49
#
#                                                                 Egg_Product  \
# 0                         Nature's Yoke Organic Free-Range Large Brown Eggs
# 1                           Natures Yoke Legacy Free-Range Large Brown Eggs
# 2   Pete and Gerry’s Organic Eggs Eggs, Organic, Free Range, Large, Grade A
# 3                            Vital Farms Pasture Raised Large Eggs- 6 count
# 4              Pete and Gerry’s Organic Eggs Eggs, Organic, Medium, Grade A
# 5                          Nature's Yoke Legacy Free Range Large Brown Eggs
# 6                          Nature's Yoke Legacy Free-Range Large White Eggs
# ...

# %%
df_new_sorted.to_csv("eggs_morton_williams_analysed.csv", index=False)

# %% [markdown]
# # now we will clean for Whole milk

# %%
import pandas as pd
df = pd.read_csv("whole_milk_at_westside.csv")

# %%
df
# Out:
#     prices                                       whole_milk_Product Milk_size
# 0      979                                Organic Valley Whole Milk     64 oz
# 1      899                            Stonyfield Organic Whole Milk   0.5 gal
# 2      899                Horizon Organic Whole High Vitamin D Milk  64 fl oz
# 3      529                                Organic Valley Whole Milk  32 fl oz
# 4      979                                Organic Valley Whole Milk     64 oz
# 5      899                            Stonyfield Organic Whole Milk   0.5 gal
# 6      899            Horizon Organic 1% Lowfat High Vitamin D Milk  64 fl oz
# 7      529                       Organic Valley 2% Reduced Fat Milk     32 oz
# 8     1119              Organic Valley Grassmilk Organic Whole Milk   0.5 gal
# 9      979  Organic Valley Ultra Pasteurized Lowfat Organic 1% Milk  64 fl oz
# 10     979                                   Organic Valley 2% Milk  64 fl oz
# ...

# %%
df.dtypes
# Out:
# prices                 int64
# whole_milk_Product    object
# Milk_size             object
# dtype: object

# %%
df.drop(df.index[[12,13,18,20]], inplace=True)

# %%
df
# Out:
#     prices                                       whole_milk_Product Milk_size
# 0      979                                Organic Valley Whole Milk     64 oz
# 1      899                            Stonyfield Organic Whole Milk   0.5 gal
# 2      899                Horizon Organic Whole High Vitamin D Milk  64 fl oz
# 3      529                                Organic Valley Whole Milk  32 fl oz
# 4      979                                Organic Valley Whole Milk     64 oz
# 5      899                            Stonyfield Organic Whole Milk   0.5 gal
# 6      899            Horizon Organic 1% Lowfat High Vitamin D Milk  64 fl oz
# 7      529                       Organic Valley 2% Reduced Fat Milk     32 oz
# 8     1119              Organic Valley Grassmilk Organic Whole Milk   0.5 gal
# 9      979  Organic Valley Ultra Pasteurized Lowfat Organic 1% Milk  64 fl oz
# 10     979                                   Organic Valley 2% Milk  64 fl oz
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#     prices                                       whole_milk_Product Milk_size
# 0      979                                Organic Valley Whole Milk     64 oz
# 1      899                            Stonyfield Organic Whole Milk   0.5 gal
# 2      899                Horizon Organic Whole High Vitamin D Milk  64 fl oz
# 3      529                                Organic Valley Whole Milk  32 fl oz
# 4      979                                Organic Valley Whole Milk     64 oz
# 5      899                            Stonyfield Organic Whole Milk   0.5 gal
# 6      899            Horizon Organic 1% Lowfat High Vitamin D Milk  64 fl oz
# 7      529                       Organic Valley 2% Reduced Fat Milk     32 oz
# 8     1119              Organic Valley Grassmilk Organic Whole Milk   0.5 gal
# 9      979  Organic Valley Ultra Pasteurized Lowfat Organic 1% Milk  64 fl oz
# 10     979                                   Organic Valley 2% Milk  64 fl oz
# ...

# %%
df['prices'] = df['prices'] / 100

# %%
df
# Out:
#     prices                                       whole_milk_Product Milk_size
# 0     9.79                                Organic Valley Whole Milk     64 oz
# 1     8.99                            Stonyfield Organic Whole Milk   0.5 gal
# 2     8.99                Horizon Organic Whole High Vitamin D Milk  64 fl oz
# 3     5.29                                Organic Valley Whole Milk  32 fl oz
# 4     9.79                                Organic Valley Whole Milk     64 oz
# 5     8.99                            Stonyfield Organic Whole Milk   0.5 gal
# 6     8.99            Horizon Organic 1% Lowfat High Vitamin D Milk  64 fl oz
# 7     5.29                       Organic Valley 2% Reduced Fat Milk     32 oz
# 8    11.19              Organic Valley Grassmilk Organic Whole Milk   0.5 gal
# 9     9.79  Organic Valley Ultra Pasteurized Lowfat Organic 1% Milk  64 fl oz
# 10    9.79                                   Organic Valley 2% Milk  64 fl oz
# ...

# %%
df['Milk_size'] = df['Milk_size'].replace('0.5 gal', '64 fl oz')

# %%
df
# Out:
#     prices                                       whole_milk_Product Milk_size
# 0     9.79                                Organic Valley Whole Milk     64 oz
# 1     8.99                            Stonyfield Organic Whole Milk  64 fl oz
# 2     8.99                Horizon Organic Whole High Vitamin D Milk  64 fl oz
# 3     5.29                                Organic Valley Whole Milk  32 fl oz
# 4     9.79                                Organic Valley Whole Milk     64 oz
# 5     8.99                            Stonyfield Organic Whole Milk  64 fl oz
# 6     8.99            Horizon Organic 1% Lowfat High Vitamin D Milk  64 fl oz
# 7     5.29                       Organic Valley 2% Reduced Fat Milk     32 oz
# 8    11.19              Organic Valley Grassmilk Organic Whole Milk  64 fl oz
# 9     9.79  Organic Valley Ultra Pasteurized Lowfat Organic 1% Milk  64 fl oz
# 10    9.79                                   Organic Valley 2% Milk  64 fl oz
# ...

# %%
df['Milk_size'] = df['Milk_size'].replace('64 oz', '64 fl oz')

# %%
df
# Out:
#     prices                                       whole_milk_Product Milk_size
# 0     9.79                                Organic Valley Whole Milk  64 fl oz
# 1     8.99                            Stonyfield Organic Whole Milk  64 fl oz
# 2     8.99                Horizon Organic Whole High Vitamin D Milk  64 fl oz
# 3     5.29                                Organic Valley Whole Milk  32 fl oz
# 4     9.79                                Organic Valley Whole Milk  64 fl oz
# 5     8.99                            Stonyfield Organic Whole Milk  64 fl oz
# 6     8.99            Horizon Organic 1% Lowfat High Vitamin D Milk  64 fl oz
# 7     5.29                       Organic Valley 2% Reduced Fat Milk     32 oz
# 8    11.19              Organic Valley Grassmilk Organic Whole Milk  64 fl oz
# 9     9.79  Organic Valley Ultra Pasteurized Lowfat Organic 1% Milk  64 fl oz
# 10    9.79                                   Organic Valley 2% Milk  64 fl oz
# ...

# %%
df['Milk_size'] = df['Milk_size'].replace('32 oz', '32 fl oz')

# %%
df
# Out:
#     prices                                       whole_milk_Product Milk_size
# 0     9.79                                Organic Valley Whole Milk  64 fl oz
# 1     8.99                            Stonyfield Organic Whole Milk  64 fl oz
# 2     8.99                Horizon Organic Whole High Vitamin D Milk  64 fl oz
# 3     5.29                                Organic Valley Whole Milk  32 fl oz
# 4     9.79                                Organic Valley Whole Milk  64 fl oz
# 5     8.99                            Stonyfield Organic Whole Milk  64 fl oz
# 6     8.99            Horizon Organic 1% Lowfat High Vitamin D Milk  64 fl oz
# 7     5.29                       Organic Valley 2% Reduced Fat Milk  32 fl oz
# 8    11.19              Organic Valley Grassmilk Organic Whole Milk  64 fl oz
# 9     9.79  Organic Valley Ultra Pasteurized Lowfat Organic 1% Milk  64 fl oz
# 10    9.79                                   Organic Valley 2% Milk  64 fl oz
# ...

# %%
df.drop(df.index[[14,16]], inplace=True)

# %%
df
# Out:
#     prices                                       whole_milk_Product Milk_size
# 0     9.79                                Organic Valley Whole Milk  64 fl oz
# 1     8.99                            Stonyfield Organic Whole Milk  64 fl oz
# 2     8.99                Horizon Organic Whole High Vitamin D Milk  64 fl oz
# 3     5.29                                Organic Valley Whole Milk  32 fl oz
# 4     9.79                                Organic Valley Whole Milk  64 fl oz
# 5     8.99                            Stonyfield Organic Whole Milk  64 fl oz
# 6     8.99            Horizon Organic 1% Lowfat High Vitamin D Milk  64 fl oz
# 7     5.29                       Organic Valley 2% Reduced Fat Milk  32 fl oz
# 8    11.19              Organic Valley Grassmilk Organic Whole Milk  64 fl oz
# 9     9.79  Organic Valley Ultra Pasteurized Lowfat Organic 1% Milk  64 fl oz
# 10    9.79                                   Organic Valley 2% Milk  64 fl oz
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#     prices                                       whole_milk_Product Milk_size
# 0     9.79                                Organic Valley Whole Milk  64 fl oz
# 1     8.99                            Stonyfield Organic Whole Milk  64 fl oz
# 2     8.99                Horizon Organic Whole High Vitamin D Milk  64 fl oz
# 3     5.29                                Organic Valley Whole Milk  32 fl oz
# 4     9.79                                Organic Valley Whole Milk  64 fl oz
# 5     8.99                            Stonyfield Organic Whole Milk  64 fl oz
# 6     8.99            Horizon Organic 1% Lowfat High Vitamin D Milk  64 fl oz
# 7     5.29                       Organic Valley 2% Reduced Fat Milk  32 fl oz
# 8    11.19              Organic Valley Grassmilk Organic Whole Milk  64 fl oz
# 9     9.79  Organic Valley Ultra Pasteurized Lowfat Organic 1% Milk  64 fl oz
# 10    9.79                                   Organic Valley 2% Milk  64 fl oz
# ...

# %% [markdown]
# # milk size is in fl oz

# %%
df.dtypes
# Out:
# prices                float64
# whole_milk_Product     object
# Milk_size              object
# dtype: object

# %%
df['Milk_size'] = df['Milk_size'].str.replace('fl oz', '').astype(float)

# %%
df
# Out:
#     prices                                       whole_milk_Product  Milk_size
# 0     9.79                                Organic Valley Whole Milk       64.0
# 1     8.99                            Stonyfield Organic Whole Milk       64.0
# 2     8.99                Horizon Organic Whole High Vitamin D Milk       64.0
# 3     5.29                                Organic Valley Whole Milk       32.0
# 4     9.79                                Organic Valley Whole Milk       64.0
# 5     8.99                            Stonyfield Organic Whole Milk       64.0
# 6     8.99            Horizon Organic 1% Lowfat High Vitamin D Milk       64.0
# 7     5.29                       Organic Valley 2% Reduced Fat Milk       32.0
# 8    11.19              Organic Valley Grassmilk Organic Whole Milk       64.0
# 9     9.79  Organic Valley Ultra Pasteurized Lowfat Organic 1% Milk       64.0
# 10    9.79                                   Organic Valley 2% Milk       64.0
# ...

# %%
df_sorted = df.sort_values('prices')

# %%
df_sorted
# Out:
#     prices                                       whole_milk_Product  Milk_size
# 3     5.29                                Organic Valley Whole Milk       32.0
# 7     5.29                       Organic Valley 2% Reduced Fat Milk       32.0
# 13    5.29  Organic Valley Ultra Pasteurized Lowfat Organic 1% Milk       32.0
# 15    8.29                                       Lactaid Whole Milk       64.0
# 1     8.99                            Stonyfield Organic Whole Milk       64.0
# 2     8.99                Horizon Organic Whole High Vitamin D Milk       64.0
# 5     8.99                            Stonyfield Organic Whole Milk       64.0
# 6     8.99            Horizon Organic 1% Lowfat High Vitamin D Milk       64.0
# 16    8.99          Horizon Organic 2% Reduced Fat DHA Omega-3 Milk       64.0
# 0     9.79                                Organic Valley Whole Milk       64.0
# 14    9.79             Organic Valley Ultra Pasteurized 0% Fat Milk       64.0
# ...

# %%
df_sorted.reset_index(drop=True, inplace=True)

# %%
df_sorted
# Out:
#     prices                                       whole_milk_Product  Milk_size
# 0     5.29                                Organic Valley Whole Milk       32.0
# 1     5.29                       Organic Valley 2% Reduced Fat Milk       32.0
# 2     5.29  Organic Valley Ultra Pasteurized Lowfat Organic 1% Milk       32.0
# 3     8.29                                       Lactaid Whole Milk       64.0
# 4     8.99                            Stonyfield Organic Whole Milk       64.0
# 5     8.99                Horizon Organic Whole High Vitamin D Milk       64.0
# 6     8.99                            Stonyfield Organic Whole Milk       64.0
# 7     8.99            Horizon Organic 1% Lowfat High Vitamin D Milk       64.0
# 8     8.99          Horizon Organic 2% Reduced Fat DHA Omega-3 Milk       64.0
# 9     9.79                                Organic Valley Whole Milk       64.0
# 10    9.79             Organic Valley Ultra Pasteurized 0% Fat Milk       64.0
# ...

# %%
df_sorted.to_csv("milk_westside_analysed.csv", index=False)

# %% [markdown]
# # now we will clean for bread

# %%
import pandas as pd
df = pd.read_csv("white_bread_at_westside.csv")

# %%
df
# Out:
#    prices  \
# 0    $419
# 1    $469
# 2    $899
# 3    $599
# 4    $709
# 5    $599
# 6    $539
# 7    $449
# 8    $539
# 9    $469
# 10   $509
# 11   $599
# 12   $559
# 13   $379
# 14   $419
# 15   $899
# 16   $619
# 17   $559
# 18   $619
# 19   $509
# 20   $599
# 21   $599
# 22   $509
# 23   $469
#
#                                                                           white_bread_Product  \
# 0                                                                Sara Lee Classic White Bread
# 1                                                                       Sara Lee Butter Bread
# 2   Dave's Killer Bread White Bread Done Right, Artisan-Style Organic White Bread, 24 oz Loaf
# 3                                                       Arnold Brick Oven Premium White Bread
# 4                                                       Arnold Brick Oven Premium White Bread
# 5                                                                  Arnold Country White Bread
# ...

# %%
df.drop(df.index[[11,18]], inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df['prices'] = df['prices'].str.replace('$', '').astype(float) / 100
# Out:
# /var/folders/lc/wd3z5xrd5s7cbp_lm8v3mkdm0000gn/T/ipykernel_16379/379781824.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['prices'] = df['prices'].str.replace('$', '').astype(float) / 100

# %%
df
# Out:
#     prices  \
# 0     4.19
# 1     4.69
# 2     8.99
# 3     5.99
# 4     7.09
# 5     5.99
# 6     5.39
# 7     4.49
# 8     5.39
# 9     4.69
# 10    5.09
# 11    5.59
# 12    3.79
# 13    4.19
# 14    8.99
# 15    6.19
# 16    5.59
# 17    5.09
# 18    5.99
# 19    5.99
# 20    5.09
# 21    4.69
#
#                                                                           white_bread_Product  \
# 0                                                                Sara Lee Classic White Bread
# 1                                                                       Sara Lee Butter Bread
# 2   Dave's Killer Bread White Bread Done Right, Artisan-Style Organic White Bread, 24 oz Loaf
# 3                                                       Arnold Brick Oven Premium White Bread
# 4                                                       Arnold Brick Oven Premium White Bread
# 5                                                                  Arnold Country White Bread
# ...

# %% [markdown]
# # now the bread size is in ounce (oz)

# %%
df['Bread_size'] = df['Bread_size'].str.replace('oz', '').astype(float)

# %%
df
# Out:
#     prices  \
# 0     4.19
# 1     4.69
# 2     8.99
# 3     5.99
# 4     7.09
# 5     5.99
# 6     5.39
# 7     4.49
# 8     5.39
# 9     4.69
# 10    5.09
# 11    5.59
# 12    3.79
# 13    4.19
# 14    8.99
# 15    6.19
# 16    5.59
# 17    5.09
# 18    5.99
# 19    5.99
# 20    5.09
# 21    4.69
#
#                                                                           white_bread_Product  \
# 0                                                                Sara Lee Classic White Bread
# 1                                                                       Sara Lee Butter Bread
# 2   Dave's Killer Bread White Bread Done Right, Artisan-Style Organic White Bread, 24 oz Loaf
# 3                                                       Arnold Brick Oven Premium White Bread
# 4                                                       Arnold Brick Oven Premium White Bread
# 5                                                                  Arnold Country White Bread
# ...

# %%
df_sorted = df.sort_values('prices')

# %%
df_sorted.reset_index(drop=True, inplace=True)

# %%
df_sorted
# Out:
#     prices  \
# 0     3.79
# 1     4.19
# 2     4.19
# 3     4.49
# 4     4.69
# 5     4.69
# 6     4.69
# 7     5.09
# 8     5.09
# 9     5.09
# 10    5.39
# 11    5.39
# 12    5.59
# 13    5.59
# 14    5.99
# 15    5.99
# 16    5.99
# 17    5.99
# 18    6.19
# 19    7.09
# 20    8.99
# 21    8.99
#
#                                                                           white_bread_Product  \
# 0                                                Pepperidge Farm Italian White Seedless Bread
# 1                                                                Sara Lee Classic White Bread
# 2                                                                Sara Lee Classic White Bread
# 3                                                 Pepperidge Farm® White Original White Bread
# 4                                                  Sara Lee White made with Whole Wheat Bread
# 5                                                  Sara Lee White made with Whole Wheat Bread
# ...

# %%
df.drop(df.index[[15]], inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#     prices  \
# 0     4.19
# 1     4.69
# 2     8.99
# 3     5.99
# 4     7.09
# 5     5.99
# 6     5.39
# 7     4.49
# 8     5.39
# 9     4.69
# 10    5.09
# 11    5.59
# 12    3.79
# 13    4.19
# 14    8.99
# 15    5.59
# 16    5.09
# 17    5.99
# 18    5.99
# 19    5.09
# 20    4.69
#
#                                                                           white_bread_Product  \
# 0                                                                Sara Lee Classic White Bread
# 1                                                                       Sara Lee Butter Bread
# 2   Dave's Killer Bread White Bread Done Right, Artisan-Style Organic White Bread, 24 oz Loaf
# 3                                                       Arnold Brick Oven Premium White Bread
# 4                                                       Arnold Brick Oven Premium White Bread
# 5                                                                  Arnold Country White Bread
# ...

# %%
# df_sorted.to_csv("bread_westside_analysed.csv", index=False)

# %% [markdown]
# # remove more columns from above

# %%
df.drop(df.index[[17]], inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#     prices  \
# 0     4.19
# 1     4.69
# 2     8.99
# 3     5.99
# 4     7.09
# 5     5.99
# 6     5.39
# 7     4.49
# 8     5.39
# 9     4.69
# 10    5.09
# 11    5.59
# 12    3.79
# 13    4.19
# 14    8.99
# 15    5.59
# 16    5.09
# 17    5.99
# 18    5.09
# 19    4.69
#
#                                                                           white_bread_Product  \
# 0                                                                Sara Lee Classic White Bread
# 1                                                                       Sara Lee Butter Bread
# 2   Dave's Killer Bread White Bread Done Right, Artisan-Style Organic White Bread, 24 oz Loaf
# 3                                                       Arnold Brick Oven Premium White Bread
# 4                                                       Arnold Brick Oven Premium White Bread
# 5                                                                  Arnold Country White Bread
# ...

# %%
df_sorted.to_csv("bread_westside_analysed.csv", index=False)
