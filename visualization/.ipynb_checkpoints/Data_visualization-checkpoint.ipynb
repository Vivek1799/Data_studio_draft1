# %% [markdown]
# # In this notebook, we will visualize the csv files and make sense of it.

# %% [markdown]
# # For eggs

# %%
import pandas as pd

# %%
df_eggs_west = pd.read_csv("eggs_west_side_analysed.csv")

# %%
df_eggs_west
# Out:
#     prices                                        Egg_Product  Egg_size
# 0     5.59  Nature's Yoke Organic Free-Range Large Brown Eggs       6.0
# 1     5.59    Natures Yoke Legacy Free-Range Large Brown Eggs       6.0
# 2     5.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...       6.0
# 3     6.79     Vital Farms Pasture Raised Large Eggs- 6 count       6.0
# 4     6.79  Pete and Gerry’s Organic Eggs Eggs, Organic, M...      12.0
# 5     7.19   Nature's Yoke Legacy Free Range Large Brown Eggs      12.0
# 6     7.19   Nature's Yoke Legacy Free-Range Large White Eggs      12.0
# 7     7.29         The Country Hen Organic Large Grade A Eggs       6.0
# 8     7.29  Nature's Yoke Legacy Free Range Extra Large Br...      12.0
# 9     7.89  The Country Hen Organic Grade A Eggs Extra- Large       6.0
# 10    7.89          Nature's Yoke Free-Range Jumbo Brown Eggs      12.0
# 11    9.99  Nature's Yoke Organic Free-Range Extra Large B...      12.0
# ...

# %%
grouped = df_eggs_west.groupby(by="Egg_size")

# %%
for name, group in grouped:
    print(f"Egg_size: {name}")
    print(f"Mean prices: {group['prices'].mean()}")
# Out:
# Egg_size: 6.0
# Mean prices: 6.506666666666667
# Egg_size: 12.0
# Mean prices: 9.656666666666665
# Egg_size: 18.0
# Mean prices: 13.49

# %%
for name, group in grouped:
    print(f"Egg_size: {name}")
    print(f"Mean prices: {group['prices'].median()}")
# Out:
# Egg_size: 6.0
# Mean prices: 6.34
# Egg_size: 12.0
# Mean prices: 10.09
# Egg_size: 18.0
# Mean prices: 13.49

# %%
egg_size_12_west = df_eggs_west.loc[df_eggs_west['Egg_size'] == 12]

# %%
egg_size_12_west
# Out:
#     prices                                        Egg_Product  Egg_size
# 4     6.79  Pete and Gerry’s Organic Eggs Eggs, Organic, M...      12.0
# 5     7.19   Nature's Yoke Legacy Free Range Large Brown Eggs      12.0
# 6     7.19   Nature's Yoke Legacy Free-Range Large White Eggs      12.0
# 8     7.29  Nature's Yoke Legacy Free Range Extra Large Br...      12.0
# 10    7.89          Nature's Yoke Free-Range Jumbo Brown Eggs      12.0
# 11    9.99  Nature's Yoke Organic Free-Range Extra Large B...      12.0
# 12    9.99  Nature's Yoke Free-Range Organic Large Brown Eggs      12.0
# 13   10.09  Nature's Yoke Organic Free-Range Large Brown Eggs      12.0
# 14   10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12.0
# 15   10.89        Nature's Yoke Free-Range Organic Jumbo Eggs      12.0
# 16   10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12.0
# 17   11.19  Pete & Gerry's Organic Eggs Extra Large Brown ...      12.0
# ...

# %%
egg_size_12_west.reset_index(drop=True)
# Out:
#     prices                                        Egg_Product  Egg_size
# 0     6.79  Pete and Gerry’s Organic Eggs Eggs, Organic, M...      12.0
# 1     7.19   Nature's Yoke Legacy Free Range Large Brown Eggs      12.0
# 2     7.19   Nature's Yoke Legacy Free-Range Large White Eggs      12.0
# 3     7.29  Nature's Yoke Legacy Free Range Extra Large Br...      12.0
# 4     7.89          Nature's Yoke Free-Range Jumbo Brown Eggs      12.0
# 5     9.99  Nature's Yoke Organic Free-Range Extra Large B...      12.0
# 6     9.99  Nature's Yoke Free-Range Organic Large Brown Eggs      12.0
# 7    10.09  Nature's Yoke Organic Free-Range Large Brown Eggs      12.0
# 8    10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12.0
# 9    10.89        Nature's Yoke Free-Range Organic Jumbo Eggs      12.0
# 10   10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12.0
# 11   11.19  Pete & Gerry's Organic Eggs Extra Large Brown ...      12.0
# ...

# %%
df_eggs_morton_williams = pd.read_csv("eggs_morton_williams_analysed.csv")

# %%
df_eggs_morton_williams
# Out:
#     prices                                        Egg_Product  Egg_size
# 0     5.59  Nature's Yoke Organic Free-Range Large Brown Eggs       6.0
# 1     5.59    Natures Yoke Legacy Free-Range Large Brown Eggs       6.0
# 2     5.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...       6.0
# 3     6.79     Vital Farms Pasture Raised Large Eggs- 6 count       6.0
# 4     6.79  Pete and Gerry’s Organic Eggs Eggs, Organic, M...      12.0
# 5     7.19   Nature's Yoke Legacy Free Range Large Brown Eggs      12.0
# 6     7.19   Nature's Yoke Legacy Free-Range Large White Eggs      12.0
# 7     7.29         The Country Hen Organic Large Grade A Eggs       6.0
# 8     7.29  Nature's Yoke Legacy Free Range Extra Large Br...      12.0
# 9     7.89  The Country Hen Organic Grade A Eggs Extra- Large       6.0
# 10    7.89          Nature's Yoke Free-Range Jumbo Brown Eggs      12.0
# 11    9.99  Nature's Yoke Organic Free-Range Extra Large B...      12.0
# ...

# %%
grouped = df_eggs_morton_williams.groupby(by="Egg_size")

# %%
for name, group in grouped:
    print(f"Egg_size: {name}")
    print(f"Mean prices: {group['prices'].mean()}")
# Out:
# Egg_size: 6.0
# Mean prices: 6.506666666666667
# Egg_size: 12.0
# Mean prices: 9.656666666666665
# Egg_size: 18.0
# Mean prices: 13.49

# %%
egg_size_12_morton = df_eggs_morton_williams.loc[df_eggs_morton_williams['Egg_size'] == 12]

# %%
egg_size_12_morton
# Out:
#     prices                                        Egg_Product  Egg_size
# 4     6.79  Pete and Gerry’s Organic Eggs Eggs, Organic, M...      12.0
# 5     7.19   Nature's Yoke Legacy Free Range Large Brown Eggs      12.0
# 6     7.19   Nature's Yoke Legacy Free-Range Large White Eggs      12.0
# 8     7.29  Nature's Yoke Legacy Free Range Extra Large Br...      12.0
# 10    7.89          Nature's Yoke Free-Range Jumbo Brown Eggs      12.0
# 11    9.99  Nature's Yoke Organic Free-Range Extra Large B...      12.0
# 12    9.99  Nature's Yoke Free-Range Organic Large Brown Eggs      12.0
# 13   10.09  Nature's Yoke Organic Free-Range Large Brown Eggs      12.0
# 14   10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12.0
# 15   10.89        Nature's Yoke Free-Range Organic Jumbo Eggs      12.0
# 16   10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12.0
# 17   11.19  Pete & Gerry's Organic Eggs Extra Large Brown ...      12.0
# ...

# %%
egg_size_12_morton.reset_index(drop=True)
# Out:
#     prices                                        Egg_Product  Egg_size
# 0     6.79  Pete and Gerry’s Organic Eggs Eggs, Organic, M...      12.0
# 1     7.19   Nature's Yoke Legacy Free Range Large Brown Eggs      12.0
# 2     7.19   Nature's Yoke Legacy Free-Range Large White Eggs      12.0
# 3     7.29  Nature's Yoke Legacy Free Range Extra Large Br...      12.0
# 4     7.89          Nature's Yoke Free-Range Jumbo Brown Eggs      12.0
# 5     9.99  Nature's Yoke Organic Free-Range Extra Large B...      12.0
# 6     9.99  Nature's Yoke Free-Range Organic Large Brown Eggs      12.0
# 7    10.09  Nature's Yoke Organic Free-Range Large Brown Eggs      12.0
# 8    10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12.0
# 9    10.89        Nature's Yoke Free-Range Organic Jumbo Eggs      12.0
# 10   10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12.0
# 11   11.19  Pete & Gerry's Organic Eggs Extra Large Brown ...      12.0
# ...

# %%
df_eggs_ctown = pd.read_csv("eggs_ctown_analysed.csv")

# %%
df_eggs_ctown
# Out:
#     prices                                        Egg_Product  Egg_size
# 0     2.79                                  Medium White Eggs      12.0
# 1     3.29    The Farmer's Hen Organic Free Range Medium Eggs      12.0
# 2     3.89            Eggland's Best Grade A Large White Eggs      12.0
# 3     4.39  Organic Valley Large Brown Free Range Organic ...       6.0
# 4     4.79  The Farmer's Hen Classic Free Range Large Brow...      12.0
# 5     4.89                      Land O Lakes Large Brown Eggs      12.0
# 6     4.99            Eggland's Best Grade A Large White Eggs      12.0
# 7     5.49           Pine Belt Eggs Grade AA Extra Large Eggs      12.0
# 8     5.49                Hillandale Farms Jumbo Grade A Eggs      12.0
# 9     5.79           Land O Lakes Eggs, Brown, Grade A, Jumbo      12.0
# 10    5.89  Eggland's Best Cage Free Grade A Large Brown Eggs      12.0
# 11    6.59           Aldefer Organic Large Brown Grade A Eggs      12.0
# ...

# %%
grouped = df_eggs_ctown.groupby(by="Egg_size")

# %%
for name, group in grouped:
    print(f"Egg_size: {name}")
    print(f"Mean prices: {group['prices'].mean()}")
# Out:
# Egg_size: 6.0
# Mean prices: 4.39
# Egg_size: 12.0
# Mean prices: 5.75
# Egg_size: 18.0
# Mean prices: 7.3566666666666665

# %%
egg_size_12_ctown = df_eggs_ctown.loc[df_eggs_ctown['Egg_size'] == 12]

# %%
egg_size_12_ctown
# Out:
#     prices                                        Egg_Product  Egg_size
# 0     2.79                                  Medium White Eggs      12.0
# 1     3.29    The Farmer's Hen Organic Free Range Medium Eggs      12.0
# 2     3.89            Eggland's Best Grade A Large White Eggs      12.0
# 4     4.79  The Farmer's Hen Classic Free Range Large Brow...      12.0
# 5     4.89                      Land O Lakes Large Brown Eggs      12.0
# 6     4.99            Eggland's Best Grade A Large White Eggs      12.0
# 7     5.49           Pine Belt Eggs Grade AA Extra Large Eggs      12.0
# 8     5.49                Hillandale Farms Jumbo Grade A Eggs      12.0
# 9     5.79           Land O Lakes Eggs, Brown, Grade A, Jumbo      12.0
# 10    5.89  Eggland's Best Cage Free Grade A Large Brown Eggs      12.0
# 11    6.59           Aldefer Organic Large Brown Grade A Eggs      12.0
# 13    7.19  The Farmer's Hen Organic Free Range Large Brow...      12.0
# ...

# %%
egg_size_12_ctown.reset_index(drop=True)
# Out:
#     prices                                        Egg_Product  Egg_size
# 0     2.79                                  Medium White Eggs      12.0
# 1     3.29    The Farmer's Hen Organic Free Range Medium Eggs      12.0
# 2     3.89            Eggland's Best Grade A Large White Eggs      12.0
# 3     4.79  The Farmer's Hen Classic Free Range Large Brow...      12.0
# 4     4.89                      Land O Lakes Large Brown Eggs      12.0
# 5     4.99            Eggland's Best Grade A Large White Eggs      12.0
# 6     5.49           Pine Belt Eggs Grade AA Extra Large Eggs      12.0
# 7     5.49                Hillandale Farms Jumbo Grade A Eggs      12.0
# 8     5.79           Land O Lakes Eggs, Brown, Grade A, Jumbo      12.0
# 9     5.89  Eggland's Best Cage Free Grade A Large Brown Eggs      12.0
# 10    6.59           Aldefer Organic Large Brown Grade A Eggs      12.0
# 11    7.19  The Farmer's Hen Organic Free Range Large Brow...      12.0
# ...

# %%
df_eggs_foodtown = pd.read_csv("eggs_food_town_analysed.csv")

# %%
df_eggs_foodtown
# Out:
#     prices                                        Egg_Product  Egg_size
# 0     4.99  Pete and Gerry’s Organic Eggs Eggs, Organic, F...       6.0
# 1     5.79         Green Way Markets Omega 3 Large Brown Eggs      12.0
# 2     5.99            Eggland's Best Grade A Large White Eggs      12.0
# 3     6.09              Land O Lakes Eggs, Brown, Extra Large      12.0
# 4     6.69                Hillandale Farms Jumbo Grade A Eggs      12.0
# 5     6.69         Land O Lakes Eggs, Brown, Cage Free, Large      12.0
# 6     6.79                Foodtown Large Grade AAA White Eggs      12.0
# 7     7.89     Utopihen Farms Pasture Raised Large Brown Eggs      12.0
# 8     8.69  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12.0
# 9     8.69  Nellie's Free Range Eggs, Brown, Free Range, L...      12.0
# 10    8.69  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12.0
# 11    8.89              Eggland's Best Extra Large White Eggs      18.0
# ...

# %%
grouped = df_eggs_foodtown.groupby(by="Egg_size")

# %%
for name, group in grouped:
    print(f"Egg_size: {name}")
    print(f"Mean prices: {group['prices'].mean()}")
# Out:
# Egg_size: 6.0
# Mean prices: 4.99
# Egg_size: 12.0
# Mean prices: 8.082666666666666
# Egg_size: 18.0
# Mean prices: 10.190000000000001

# %%
egg_size_12_foodtown = df_eggs_foodtown.loc[df_eggs_foodtown['Egg_size'] == 12]

# %%
egg_size_12_foodtown
# Out:
#     prices                                        Egg_Product  Egg_size
# 1     5.79         Green Way Markets Omega 3 Large Brown Eggs      12.0
# 2     5.99            Eggland's Best Grade A Large White Eggs      12.0
# 3     6.09              Land O Lakes Eggs, Brown, Extra Large      12.0
# 4     6.69                Hillandale Farms Jumbo Grade A Eggs      12.0
# 5     6.69         Land O Lakes Eggs, Brown, Cage Free, Large      12.0
# 6     6.79                Foodtown Large Grade AAA White Eggs      12.0
# 7     7.89     Utopihen Farms Pasture Raised Large Brown Eggs      12.0
# 8     8.69  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12.0
# 9     8.69  Nellie's Free Range Eggs, Brown, Free Range, L...      12.0
# 10    8.69  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12.0
# 12    9.19  The Farmer's Hen Organic Free Range Large Brow...      12.0
# 13    9.19  The Farmer's Hen Organic Pasture Raised Large ...      12.0
# ...

# %%
egg_size_12_foodtown.reset_index(drop=True)
# Out:
#     prices                                        Egg_Product  Egg_size
# 0     5.79         Green Way Markets Omega 3 Large Brown Eggs      12.0
# 1     5.99            Eggland's Best Grade A Large White Eggs      12.0
# 2     6.09              Land O Lakes Eggs, Brown, Extra Large      12.0
# 3     6.69                Hillandale Farms Jumbo Grade A Eggs      12.0
# 4     6.69         Land O Lakes Eggs, Brown, Cage Free, Large      12.0
# 5     6.79                Foodtown Large Grade AAA White Eggs      12.0
# 6     7.89     Utopihen Farms Pasture Raised Large Brown Eggs      12.0
# 7     8.69  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12.0
# 8     8.69  Nellie's Free Range Eggs, Brown, Free Range, L...      12.0
# 9     8.69  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12.0
# 10    9.19  The Farmer's Hen Organic Free Range Large Brow...      12.0
# 11    9.19  The Farmer's Hen Organic Pasture Raised Large ...      12.0
# ...

# %% [markdown]
# # now merging all 4 dataframes together for a dozen of eggs

# %%
merged_df = pd.concat([egg_size_12_west, egg_size_12_morton, egg_size_12_ctown, egg_size_12_foodtown], axis=0)

# %%
merged_df
# Out:
#     prices                                        Egg_Product  Egg_size
# 4     6.79  Pete and Gerry’s Organic Eggs Eggs, Organic, M...      12.0
# 5     7.19   Nature's Yoke Legacy Free Range Large Brown Eggs      12.0
# 6     7.19   Nature's Yoke Legacy Free-Range Large White Eggs      12.0
# 8     7.29  Nature's Yoke Legacy Free Range Extra Large Br...      12.0
# 10    7.89          Nature's Yoke Free-Range Jumbo Brown Eggs      12.0
# 11    9.99  Nature's Yoke Organic Free-Range Extra Large B...      12.0
# 12    9.99  Nature's Yoke Free-Range Organic Large Brown Eggs      12.0
# 13   10.09  Nature's Yoke Organic Free-Range Large Brown Eggs      12.0
# 14   10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12.0
# 15   10.89        Nature's Yoke Free-Range Organic Jumbo Eggs      12.0
# 16   10.89  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12.0
# 17   11.19  Pete & Gerry's Organic Eggs Extra Large Brown ...      12.0
# ...

# %%
average_price = merged_df['prices'].mean()

# %%
average_price
# Out:
# 8.286499999999998

# %% [markdown]
# # now we will calcuate the average price of breads of grocery shops near columbia university

# %%
import pandas as pd

# %%
df = pd.read_csv("bread_westside_analysed.csv")

# %%
df
# Out:
#     prices                                white_bread_Product  Bread_size
# 0     3.79       Pepperidge Farm Italian White Seedless Bread        20.0
# 1     4.19                       Sara Lee Classic White Bread        20.0
# 2     4.19                       Sara Lee Classic White Bread        20.0
# 3     4.49        Pepperidge Farm® White Original White Bread        16.0
# 4     4.69         Sara Lee White made with Whole Wheat Bread        20.0
# 5     4.69         Sara Lee White made with Whole Wheat Bread        20.0
# 6     4.69                              Sara Lee Butter Bread        20.0
# 7     5.09                     Sara Lee Artesano Bakery Bread        20.0
# 8     5.09                         Sara Lee Honey Wheat Bread        20.0
# 9     5.09                     Sara Lee Artesano Bakery Bread        20.0
# 10    5.39                 Pepperidge Farm® White White Bread        16.0
# 11    5.39  Pepperidge Farm® Very Thin Enriched White Thin...        16.0
# ...

# %% [markdown]
# # note: our bread is in ounce (oz)

# %%
df.drop(df.index[[15,18]], inplace=True)

# %%
df
# Out:
#     prices                                white_bread_Product  Bread_size
# 0     3.79       Pepperidge Farm Italian White Seedless Bread        20.0
# 1     4.19                       Sara Lee Classic White Bread        20.0
# 2     4.19                       Sara Lee Classic White Bread        20.0
# 3     4.49        Pepperidge Farm® White Original White Bread        16.0
# 4     4.69         Sara Lee White made with Whole Wheat Bread        20.0
# 5     4.69         Sara Lee White made with Whole Wheat Bread        20.0
# 6     4.69                              Sara Lee Butter Bread        20.0
# 7     5.09                     Sara Lee Artesano Bakery Bread        20.0
# 8     5.09                         Sara Lee Honey Wheat Bread        20.0
# 9     5.09                     Sara Lee Artesano Bakery Bread        20.0
# 10    5.39                 Pepperidge Farm® White White Bread        16.0
# 11    5.39  Pepperidge Farm® Very Thin Enriched White Thin...        16.0
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#     prices                                white_bread_Product  Bread_size
# 0     3.79       Pepperidge Farm Italian White Seedless Bread        20.0
# 1     4.19                       Sara Lee Classic White Bread        20.0
# 2     4.19                       Sara Lee Classic White Bread        20.0
# 3     4.49        Pepperidge Farm® White Original White Bread        16.0
# 4     4.69         Sara Lee White made with Whole Wheat Bread        20.0
# 5     4.69         Sara Lee White made with Whole Wheat Bread        20.0
# 6     4.69                              Sara Lee Butter Bread        20.0
# 7     5.09                     Sara Lee Artesano Bakery Bread        20.0
# 8     5.09                         Sara Lee Honey Wheat Bread        20.0
# 9     5.09                     Sara Lee Artesano Bakery Bread        20.0
# 10    5.39                 Pepperidge Farm® White White Bread        16.0
# 11    5.39  Pepperidge Farm® Very Thin Enriched White Thin...        16.0
# ...

# %%
df_bread_westside_white20 = df[(df['Bread_size'] == 20)]

# %%
df_bread_westside_white20
# Out:
#     prices                           white_bread_Product  Bread_size
# 0     3.79  Pepperidge Farm Italian White Seedless Bread        20.0
# 1     4.19                  Sara Lee Classic White Bread        20.0
# 2     4.19                  Sara Lee Classic White Bread        20.0
# 4     4.69    Sara Lee White made with Whole Wheat Bread        20.0
# 5     4.69    Sara Lee White made with Whole Wheat Bread        20.0
# 6     4.69                         Sara Lee Butter Bread        20.0
# 7     5.09                Sara Lee Artesano Bakery Bread        20.0
# 8     5.09                    Sara Lee Honey Wheat Bread        20.0
# 9     5.09                Sara Lee Artesano Bakery Bread        20.0
# 14    5.99         Arnold Brick Oven Premium White Bread        20.0

# %%
df_bread_westside_white20.reset_index(drop=True, inplace=True)

# %%
df_bread_westside_white20
# Out:
#    prices                           white_bread_Product  Bread_size
# 0    3.79  Pepperidge Farm Italian White Seedless Bread        20.0
# 1    4.19                  Sara Lee Classic White Bread        20.0
# 2    4.19                  Sara Lee Classic White Bread        20.0
# 3    4.69    Sara Lee White made with Whole Wheat Bread        20.0
# 4    4.69    Sara Lee White made with Whole Wheat Bread        20.0
# 5    4.69                         Sara Lee Butter Bread        20.0
# 6    5.09                Sara Lee Artesano Bakery Bread        20.0
# 7    5.09                    Sara Lee Honey Wheat Bread        20.0
# 8    5.09                Sara Lee Artesano Bakery Bread        20.0
# 9    5.99         Arnold Brick Oven Premium White Bread        20.0

# %% [markdown]
# # breads for morton williams

# %%
df2 = pd.read_csv("bread_morton_williams_analysed.csv")

# %%
df2
# Out:
#     prices                                white_bread_Product  Bread_size
# 0     2.69                             Bimbo Soft White Bread        20.0
# 1     2.99       Pepperidge Farm Italian White Seedless Bread        20.0
# 2     3.49                       Sara Lee Classic White Bread        20.0
# 3     3.49                       Sara Lee Classic White Bread        20.0
# 4     3.69                         Sara Lee Honey Wheat Bread        20.0
# 5     3.69                    Sara Lee 100% Whole Wheat Bread        20.0
# 6     3.69                              Sara Lee Butter Bread        20.0
# 7     3.69                    Sara Lee 100% Whole Wheat Bread        20.0
# 8     3.69                         Sara Lee Honey Wheat Bread        20.0
# 9     3.69                              Sara Lee Butter Bread        20.0
# 10    3.99        Sara Lee Artesano Golden Wheat Bakery Bread        20.0
# 11    3.99                 Pepperidge Farm® White White Bread        16.0
# ...

# %%
df_bread_wiliams_white20 = df2[(df2['Bread_size'] == 20)]

# %%
df_bread_wiliams_white20
# Out:
#     prices                           white_bread_Product  Bread_size
# 0     2.69                        Bimbo Soft White Bread        20.0
# 1     2.99  Pepperidge Farm Italian White Seedless Bread        20.0
# 2     3.49                  Sara Lee Classic White Bread        20.0
# 3     3.49                  Sara Lee Classic White Bread        20.0
# 4     3.69                    Sara Lee Honey Wheat Bread        20.0
# 5     3.69               Sara Lee 100% Whole Wheat Bread        20.0
# 6     3.69                         Sara Lee Butter Bread        20.0
# 7     3.69               Sara Lee 100% Whole Wheat Bread        20.0
# 8     3.69                    Sara Lee Honey Wheat Bread        20.0
# 9     3.69                         Sara Lee Butter Bread        20.0
# 10    3.99   Sara Lee Artesano Golden Wheat Bakery Bread        20.0
# 12    3.99   Sara Lee Artesano Golden Wheat Bakery Bread        20.0
# 18    4.69         Arnold Brick Oven Premium White Bread        20.0

# %%
df_bread_wiliams_white20.reset_index(drop=True, inplace=True)

# %%
df_bread_wiliams_white20
# Out:
#     prices                           white_bread_Product  Bread_size
# 0     2.69                        Bimbo Soft White Bread        20.0
# 1     2.99  Pepperidge Farm Italian White Seedless Bread        20.0
# 2     3.49                  Sara Lee Classic White Bread        20.0
# 3     3.49                  Sara Lee Classic White Bread        20.0
# 4     3.69                    Sara Lee Honey Wheat Bread        20.0
# 5     3.69               Sara Lee 100% Whole Wheat Bread        20.0
# 6     3.69                         Sara Lee Butter Bread        20.0
# 7     3.69               Sara Lee 100% Whole Wheat Bread        20.0
# 8     3.69                    Sara Lee Honey Wheat Bread        20.0
# 9     3.69                         Sara Lee Butter Bread        20.0
# 10    3.99   Sara Lee Artesano Golden Wheat Bakery Bread        20.0
# 11    3.99   Sara Lee Artesano Golden Wheat Bakery Bread        20.0
# 12    4.69         Arnold Brick Oven Premium White Bread        20.0

# %% [markdown]
# # breads for ctown

# %%
df3 = pd.read_csv("bread_c_town_analysed.csv")

# %%
df3
# Out:
#     prices                                white_bread_Product  Bread_size
# 0     3.19  Pepperidge Farm® Italian Italian with Sesame S...        20.0
# 1     3.19  Pepperidge Farm® Italian Italian with Sesame S...        20.0
# 2     3.29                              Sara Lee Butter Bread        20.0
# 3     3.29  Nature's Own Butterbread, Sliced White Bread, ...        20.0
# 4     3.29                     Sara Lee Artesano Bakery Bread        20.0
# 5     3.29                              Sara Lee Butter Bread        20.0
# 6     3.29  Nature's Own Butterbread, Sliced White Bread, ...        20.0
# 7     4.09  Nature's Own Perfectly Crafted White Bread, Th...        22.0
# 8     4.09  Nature's Own Perfectly Crafted White Bread, Th...        22.0
# 9     4.39         Sara Lee White made with Whole Wheat Bread        20.0
# 10    4.39                    Sara Lee 100% Whole Wheat Bread        20.0
# 11    4.39  Pepperidge Farm Farmhouse Whole Grain White Bread        24.0
# ...

# %%
df_bread_ctown_white20 = df3[(df3['Bread_size'] == 20)]

# %%
df_bread_ctown_white20
# Out:
#     prices                                white_bread_Product  Bread_size
# 0     3.19  Pepperidge Farm® Italian Italian with Sesame S...        20.0
# 1     3.19  Pepperidge Farm® Italian Italian with Sesame S...        20.0
# 2     3.29                              Sara Lee Butter Bread        20.0
# 3     3.29  Nature's Own Butterbread, Sliced White Bread, ...        20.0
# 4     3.29                     Sara Lee Artesano Bakery Bread        20.0
# 5     3.29                              Sara Lee Butter Bread        20.0
# 6     3.29  Nature's Own Butterbread, Sliced White Bread, ...        20.0
# 9     4.39         Sara Lee White made with Whole Wheat Bread        20.0
# 10    4.39                    Sara Lee 100% Whole Wheat Bread        20.0
# 13    4.39         Sara Lee White made with Whole Wheat Bread        20.0
# 15    4.39                    Sara Lee 100% Whole Wheat Bread        20.0
# 16    4.39         Sara Lee White made with Whole Wheat Bread        20.0

# %%
df_bread_ctown_white20.reset_index(drop=True, inplace=True)

# %%
df_bread_ctown_white20
# Out:
#     prices                                white_bread_Product  Bread_size
# 0     3.19  Pepperidge Farm® Italian Italian with Sesame S...        20.0
# 1     3.19  Pepperidge Farm® Italian Italian with Sesame S...        20.0
# 2     3.29                              Sara Lee Butter Bread        20.0
# 3     3.29  Nature's Own Butterbread, Sliced White Bread, ...        20.0
# 4     3.29                     Sara Lee Artesano Bakery Bread        20.0
# 5     3.29                              Sara Lee Butter Bread        20.0
# 6     3.29  Nature's Own Butterbread, Sliced White Bread, ...        20.0
# 7     4.39         Sara Lee White made with Whole Wheat Bread        20.0
# 8     4.39                    Sara Lee 100% Whole Wheat Bread        20.0
# 9     4.39         Sara Lee White made with Whole Wheat Bread        20.0
# 10    4.39                    Sara Lee 100% Whole Wheat Bread        20.0
# 11    4.39         Sara Lee White made with Whole Wheat Bread        20.0

# %% [markdown]
# # bread for food town

# %%
df4 = pd.read_csv("bread_food_town_analysed.csv")

# %%
df4
# Out:
#     prices                                white_bread_Product  Bread_size
# 0     3.49                              Sara Lee Butter Bread        20.0
# 1     3.49                         Sara Lee Honey Wheat Bread        20.0
# 2     3.49                              Sara Lee Butter Bread        20.0
# 3     3.49                         Sara Lee Honey Wheat Bread        20.0
# 4     3.49                    Sara Lee 100% Whole Wheat Bread        20.0
# 5     3.88       Pepperidge Farm Italian White Seedless Bread        20.0
# 6     4.09              Arnold Brick Oven Premium White Bread        20.0
# 7     4.09  Wonder Bread Bread Classic White Sandwich Brea...        20.0
# 8     4.59               Nature's Own Bread, 100% Whole Wheat        20.0
# 9     4.99  Nature's Own Perfectly Crafted White Bread, Th...        22.0
# 10    4.99       Nature's Own Bread, Multigrain, Thick Sliced        22.0
# 11    4.99                              Sara Lee Butter Bread        20.0
# ...

# %%
df_bread_foodtown_white20 = df4[(df4['Bread_size'] == 20)]

# %%
df_bread_foodtown_white20
# Out:
#     prices                                white_bread_Product  Bread_size
# 0     3.49                              Sara Lee Butter Bread        20.0
# 1     3.49                         Sara Lee Honey Wheat Bread        20.0
# 2     3.49                              Sara Lee Butter Bread        20.0
# 3     3.49                         Sara Lee Honey Wheat Bread        20.0
# 4     3.49                    Sara Lee 100% Whole Wheat Bread        20.0
# 5     3.88       Pepperidge Farm Italian White Seedless Bread        20.0
# 6     4.09              Arnold Brick Oven Premium White Bread        20.0
# 7     4.09  Wonder Bread Bread Classic White Sandwich Brea...        20.0
# 8     4.59               Nature's Own Bread, 100% Whole Wheat        20.0
# 11    4.99                              Sara Lee Butter Bread        20.0
# 13    5.29            Martin's Potato Bread, 100% Whole Wheat        20.0

# %%
df_bread_foodtown_white20.reset_index(drop=True, inplace=True)

# %%
df_bread_foodtown_white20
# Out:
#     prices                                white_bread_Product  Bread_size
# 0     3.49                              Sara Lee Butter Bread        20.0
# 1     3.49                         Sara Lee Honey Wheat Bread        20.0
# 2     3.49                              Sara Lee Butter Bread        20.0
# 3     3.49                         Sara Lee Honey Wheat Bread        20.0
# 4     3.49                    Sara Lee 100% Whole Wheat Bread        20.0
# 5     3.88       Pepperidge Farm Italian White Seedless Bread        20.0
# 6     4.09              Arnold Brick Oven Premium White Bread        20.0
# 7     4.09  Wonder Bread Bread Classic White Sandwich Brea...        20.0
# 8     4.59               Nature's Own Bread, 100% Whole Wheat        20.0
# 9     4.99                              Sara Lee Butter Bread        20.0
# 10    5.29            Martin's Potato Bread, 100% Whole Wheat        20.0

# %% [markdown]
# # Now lets merge all our bread df:

# %%
merged_df_bread = pd.concat([df_bread_westside_white20,df_bread_wiliams_white20,df_bread_ctown_white20,df_bread_foodtown_white20], axis=0)

# %%
merged_df_bread
# Out:
#     prices                                white_bread_Product  Bread_size
# 0     3.79       Pepperidge Farm Italian White Seedless Bread        20.0
# 1     4.19                       Sara Lee Classic White Bread        20.0
# 2     4.19                       Sara Lee Classic White Bread        20.0
# 3     4.69         Sara Lee White made with Whole Wheat Bread        20.0
# 4     4.69         Sara Lee White made with Whole Wheat Bread        20.0
# 5     4.69                              Sara Lee Butter Bread        20.0
# 6     5.09                     Sara Lee Artesano Bakery Bread        20.0
# 7     5.09                         Sara Lee Honey Wheat Bread        20.0
# 8     5.09                     Sara Lee Artesano Bakery Bread        20.0
# 9     5.99              Arnold Brick Oven Premium White Bread        20.0
# 0     2.69                             Bimbo Soft White Bread        20.0
# 1     2.99       Pepperidge Farm Italian White Seedless Bread        20.0
# ...

# %%
average_price = merged_df_bread['prices'].mean()

# %%
average_price
# Out:
# 4.002826086956522

# %% [markdown]
# # now we will calculate for whole milk, the average price

# %% [markdown]
# # for westside:

# %%
import pandas as pd

# %%
dfa = pd.read_csv("milk_westside_analysed.csv")

# %%
dfa
# Out:
#     prices                                 whole_milk_Product  Milk_size
# 0     5.29                          Organic Valley Whole Milk       32.0
# 1     5.29                 Organic Valley 2% Reduced Fat Milk       32.0
# 2     5.29  Organic Valley Ultra Pasteurized Lowfat Organi...       32.0
# 3     8.29                                 Lactaid Whole Milk       64.0
# 4     8.99                      Stonyfield Organic Whole Milk       64.0
# 5     8.99          Horizon Organic Whole High Vitamin D Milk       64.0
# 6     8.99                      Stonyfield Organic Whole Milk       64.0
# 7     8.99      Horizon Organic 1% Lowfat High Vitamin D Milk       64.0
# 8     8.99    Horizon Organic 2% Reduced Fat DHA Omega-3 Milk       64.0
# 9     9.79                          Organic Valley Whole Milk       64.0
# 10    9.79       Organic Valley Ultra Pasteurized 0% Fat Milk       64.0
# 11    9.79                             Organic Valley 2% Milk       64.0
# ...

# %% [markdown]
# # here the milk is in fl oz

# %%
df_milk_westside_whole64 = dfa[(dfa['Milk_size'] == 64)]

# %%
df_milk_westside_whole64
# Out:
#     prices                                 whole_milk_Product  Milk_size
# 3     8.29                                 Lactaid Whole Milk       64.0
# 4     8.99                      Stonyfield Organic Whole Milk       64.0
# 5     8.99          Horizon Organic Whole High Vitamin D Milk       64.0
# 6     8.99                      Stonyfield Organic Whole Milk       64.0
# 7     8.99      Horizon Organic 1% Lowfat High Vitamin D Milk       64.0
# 8     8.99    Horizon Organic 2% Reduced Fat DHA Omega-3 Milk       64.0
# 9     9.79                          Organic Valley Whole Milk       64.0
# 10    9.79       Organic Valley Ultra Pasteurized 0% Fat Milk       64.0
# 11    9.79                             Organic Valley 2% Milk       64.0
# 12    9.79  Organic Valley Ultra Pasteurized Lowfat Organi...       64.0
# 13    9.79                             Organic Valley 2% Milk       64.0
# 14    9.79  Organic Valley Ultra Pasteurized Lowfat Organi...       64.0
# ...

# %%
df_milk_westside_whole64.reset_index(drop=True, inplace=True)

# %%
df_milk_westside_whole64
# Out:
#     prices                                 whole_milk_Product  Milk_size
# 0     8.29                                 Lactaid Whole Milk       64.0
# 1     8.99                      Stonyfield Organic Whole Milk       64.0
# 2     8.99          Horizon Organic Whole High Vitamin D Milk       64.0
# 3     8.99                      Stonyfield Organic Whole Milk       64.0
# 4     8.99      Horizon Organic 1% Lowfat High Vitamin D Milk       64.0
# 5     8.99    Horizon Organic 2% Reduced Fat DHA Omega-3 Milk       64.0
# 6     9.79                          Organic Valley Whole Milk       64.0
# 7     9.79       Organic Valley Ultra Pasteurized 0% Fat Milk       64.0
# 8     9.79                             Organic Valley 2% Milk       64.0
# 9     9.79  Organic Valley Ultra Pasteurized Lowfat Organi...       64.0
# 10    9.79                             Organic Valley 2% Milk       64.0
# 11    9.79  Organic Valley Ultra Pasteurized Lowfat Organi...       64.0
# ...

# %% [markdown]
# # milk for morton williams

# %%
dfb = pd.read_csv("milk_morton_williams_analysed.csv")

# %%
dfb
# Out:
#     prices                                 whole_milk_Product  Milk_size
# 0     4.79                          Organic Valley Whole Milk       32.0
# 1     4.79                 Organic Valley 2% Reduced Fat Milk       32.0
# 2     4.99      Family A2 Farmstead 100% Grass Fed Whole Milk       32.0
# 3     5.99                                 Lactaid Whole Milk       64.0
# 4     6.99          Horizon Organic Whole High Vitamin D Milk       64.0
# 5     6.99                      Stonyfield Organic Whole Milk       64.0
# 6     6.99      Horizon Organic 1% Lowfat High Vitamin D Milk       64.0
# 7     6.99           Horizon Organic Reduced Fat Organic Milk       64.0
# 8     7.99  Horizon Organic DHA Omega-3 Vitamin D Organic ...       64.0
# 9     8.49                          Organic Valley Whole Milk       64.0
# 10    8.49                          Organic Valley Whole Milk       64.0
# 11    8.49                             Organic Valley 2% Milk       64.0
# ...

# %%
df_milk_williams_whole64 = dfb[(dfb['Milk_size'] == 64)]

# %%
df_milk_williams_whole64
# Out:
#     prices                                 whole_milk_Product  Milk_size
# 3     5.99                                 Lactaid Whole Milk       64.0
# 4     6.99          Horizon Organic Whole High Vitamin D Milk       64.0
# 5     6.99                      Stonyfield Organic Whole Milk       64.0
# 6     6.99      Horizon Organic 1% Lowfat High Vitamin D Milk       64.0
# 7     6.99           Horizon Organic Reduced Fat Organic Milk       64.0
# 8     7.99  Horizon Organic DHA Omega-3 Vitamin D Organic ...       64.0
# 9     8.49                          Organic Valley Whole Milk       64.0
# 10    8.49                          Organic Valley Whole Milk       64.0
# 11    8.49                             Organic Valley 2% Milk       64.0
# 12    8.49  Organic Valley Ultra Pasteurized Lowfat Organi...       64.0
# 13    8.99       Organic Valley Ultra Pasteurized 0% Fat Milk       64.0

# %%
df_milk_williams_whole64.reset_index(drop=True, inplace=True)

# %%
df_milk_williams_whole64
# Out:
#     prices                                 whole_milk_Product  Milk_size
# 0     5.99                                 Lactaid Whole Milk       64.0
# 1     6.99          Horizon Organic Whole High Vitamin D Milk       64.0
# 2     6.99                      Stonyfield Organic Whole Milk       64.0
# 3     6.99      Horizon Organic 1% Lowfat High Vitamin D Milk       64.0
# 4     6.99           Horizon Organic Reduced Fat Organic Milk       64.0
# 5     7.99  Horizon Organic DHA Omega-3 Vitamin D Organic ...       64.0
# 6     8.49                          Organic Valley Whole Milk       64.0
# 7     8.49                          Organic Valley Whole Milk       64.0
# 8     8.49                             Organic Valley 2% Milk       64.0
# 9     8.49  Organic Valley Ultra Pasteurized Lowfat Organi...       64.0
# 10    8.99       Organic Valley Ultra Pasteurized 0% Fat Milk       64.0

# %% [markdown]
# # now milk for ctown

# %%
dfc = pd.read_csv("milk_c_town_analysed.csv")

# %%
dfc
# Out:
#     prices                                 whole_milk_Product  Milk_size
# 0     3.29                           Cream-O-Land Milk, Whole       64.0
# 1     6.09                                      Oatly Oatmilk       64.0
# 2     6.59                                 Lactaid Whole Milk       64.0
# 3     6.59                                 Lactaid Whole Milk       64.0
# 4     7.69          Horizon Organic Whole High Vitamin D Milk       64.0
# 5     7.69       Organic Valley Ultra Pasteurized 0% Fat Milk       64.0
# 6     8.29                          Organic Valley Whole Milk       64.0
# 7     8.29                             Organic Valley 2% Milk       64.0
# 8     8.29                          Organic Valley Whole Milk       64.0
# 9     8.29  Horizon Organic DHA Omega-3 Vitamin D Organic ...       64.0
# 10    8.29  Organic Valley Ultra Pasteurized Lowfat Organi...       64.0
# 11    8.29  Horizon Organic Lactose-Free Vitamin D Organic...       64.0
# ...

# %%
df_milk_ctown_whole64 = dfc[(dfc['Milk_size'] == 64)]

# %%
df_milk_ctown_whole64
# Out:
#     prices                                 whole_milk_Product  Milk_size
# 0     3.29                           Cream-O-Land Milk, Whole       64.0
# 1     6.09                                      Oatly Oatmilk       64.0
# 2     6.59                                 Lactaid Whole Milk       64.0
# 3     6.59                                 Lactaid Whole Milk       64.0
# 4     7.69          Horizon Organic Whole High Vitamin D Milk       64.0
# 5     7.69       Organic Valley Ultra Pasteurized 0% Fat Milk       64.0
# 6     8.29                          Organic Valley Whole Milk       64.0
# 7     8.29                             Organic Valley 2% Milk       64.0
# 8     8.29                          Organic Valley Whole Milk       64.0
# 9     8.29  Horizon Organic DHA Omega-3 Vitamin D Organic ...       64.0
# 10    8.29  Organic Valley Ultra Pasteurized Lowfat Organi...       64.0
# 11    8.29  Horizon Organic Lactose-Free Vitamin D Organic...       64.0
# ...

# %% [markdown]
# # now milk for foodtown

# %%
dfd = pd.read_csv("milk_foodtown_analysed.csv")

# %%
dfd
# Out:
#     prices                                 whole_milk_Product  Milk_size
# 0     4.79                          Organic Valley Whole Milk       32.0
# 1     4.79                 Organic Valley 2% Reduced Fat Milk       32.0
# 2     4.79  Organic Valley Ultra Pasteurized Lowfat Organi...       32.0
# 3     4.99      Family A2 Farmstead 100% Grass Fed Whole Milk       32.0
# 4     5.99                                 Lactaid Whole Milk       64.0
# 5     6.99           Horizon Organic Reduced Fat Organic Milk       64.0
# 6     6.99      Horizon Organic 1% Lowfat High Vitamin D Milk       64.0
# 7     7.99  Horizon Organic DHA Omega-3 Vitamin D Organic ...       64.0
# 8     8.49                          Organic Valley Whole Milk       64.0
# 9     8.49                             Organic Valley 2% Milk       64.0
# 10    8.49                          Organic Valley Whole Milk       64.0
# 11    8.49  Organic Valley Ultra Pasteurized Lowfat Organi...       64.0
# ...

# %%
df_milk_foodtown_whole64 = dfd[(dfd['Milk_size'] == 64)]

# %%
df_milk_foodtown_whole64
# Out:
#     prices                                 whole_milk_Product  Milk_size
# 4     5.99                                 Lactaid Whole Milk       64.0
# 5     6.99           Horizon Organic Reduced Fat Organic Milk       64.0
# 6     6.99      Horizon Organic 1% Lowfat High Vitamin D Milk       64.0
# 7     7.99  Horizon Organic DHA Omega-3 Vitamin D Organic ...       64.0
# 8     8.49                          Organic Valley Whole Milk       64.0
# 9     8.49                             Organic Valley 2% Milk       64.0
# 10    8.49                          Organic Valley Whole Milk       64.0
# 11    8.49  Organic Valley Ultra Pasteurized Lowfat Organi...       64.0
# 12    8.49                             Organic Valley 2% Milk       64.0
# 13    8.99       Organic Valley Ultra Pasteurized 0% Fat Milk       64.0
# 14    8.99       Organic Valley Ultra Pasteurized 0% Fat Milk       64.0

# %%
df_milk_foodtown_whole64.reset_index(drop=True, inplace=True)

# %%
df_milk_foodtown_whole64
# Out:
#     prices                                 whole_milk_Product  Milk_size
# 0     5.99                                 Lactaid Whole Milk       64.0
# 1     6.99           Horizon Organic Reduced Fat Organic Milk       64.0
# 2     6.99      Horizon Organic 1% Lowfat High Vitamin D Milk       64.0
# 3     7.99  Horizon Organic DHA Omega-3 Vitamin D Organic ...       64.0
# 4     8.49                          Organic Valley Whole Milk       64.0
# 5     8.49                             Organic Valley 2% Milk       64.0
# 6     8.49                          Organic Valley Whole Milk       64.0
# 7     8.49  Organic Valley Ultra Pasteurized Lowfat Organi...       64.0
# 8     8.49                             Organic Valley 2% Milk       64.0
# 9     8.99       Organic Valley Ultra Pasteurized 0% Fat Milk       64.0
# 10    8.99       Organic Valley Ultra Pasteurized 0% Fat Milk       64.0

# %% [markdown]
# # Now lets merge all the dataframes for whole milk

# %%
merged_df_milk = pd.concat([df_milk_westside_whole64,df_milk_williams_whole64,df_milk_ctown_whole64,df_milk_foodtown_whole64], axis=0)

# %%
merged_df_milk
# Out:
#     prices                                 whole_milk_Product  Milk_size
# 0     8.29                                 Lactaid Whole Milk       64.0
# 1     8.99                      Stonyfield Organic Whole Milk       64.0
# 2     8.99          Horizon Organic Whole High Vitamin D Milk       64.0
# 3     8.99                      Stonyfield Organic Whole Milk       64.0
# 4     8.99      Horizon Organic 1% Lowfat High Vitamin D Milk       64.0
# 5     8.99    Horizon Organic 2% Reduced Fat DHA Omega-3 Milk       64.0
# 6     9.79                          Organic Valley Whole Milk       64.0
# 7     9.79       Organic Valley Ultra Pasteurized 0% Fat Milk       64.0
# 8     9.79                             Organic Valley 2% Milk       64.0
# 9     9.79  Organic Valley Ultra Pasteurized Lowfat Organi...       64.0
# 10    9.79                             Organic Valley 2% Milk       64.0
# 11    9.79  Organic Valley Ultra Pasteurized Lowfat Organi...       64.0
# ...

# %%
average_price = merged_df_milk['prices'].mean()

# %%
average_price
# Out:
# 8.335283018867926

# %% [markdown]
# we took organic whole milk, because those were the product range in our grocery data
