# %% [markdown]
# # In this notebook, I will scrape Morton Williams which is on Broadway between 115th and 116th St, right across from campus for the essential food items on the instacart website.

# %% [markdown]
# # Morton Willams Market for eggs:

# %%
from playwright.async_api import async_playwright

# %%
playwright = await async_playwright().start()

# %%
browser = await playwright.chromium.launch(headless = False)

# %%
browser.new_page()
# Out:
# <coroutine object Browser.new_page at 0x105308270>

# %%
page = await browser.new_page()

# %%
await page.goto("https://www.instacart.com/store/morton-williams-supermarket/search/eggs")
# Out:
# <Response url='https://www.instacart.com/store/morton-williams-supermarket/search/eggs' request=<Request url='https://www.instacart.com/store/morton-williams-supermarket/search/eggs' method='GET'>>

# %%
import pandas as pd

async def scrape_and_merge():
    prices = []
    egg_product = []
    egg_size = []

    for i in range(0, 24):
        try:
            price = await page.locator("div.css-1abd9id-ItemBCardDetailsSection div.css-k008qs div.css-lkyxb9-PriceIa").nth(i).inner_text()
            prices.append(price)
        except:
            continue
    df = pd.DataFrame(prices, columns=['prices'])

    for i in range(0, 24):
        try:
            name = await page.locator("h3.css-1w4764r").nth(i).inner_text()
            egg_product.append(name)
        except:
            continue
    df2 = pd.DataFrame(egg_product, columns=['Egg_Product'])

    for i in range(0, 24):
        try:
            size = await page.locator("div.css-1301wpr-Size").nth(i).inner_text()
            egg_size.append(size)
        except:
            continue
    df3 = pd.DataFrame(egg_size, columns=['Egg_size'])
    
    df4 = df.merge(df2, left_index=True, right_index=True).merge(df3, left_index=True, right_index=True)

    return df4

df4 = await scrape_and_merge()

df4
# Out:
#    prices                                        Egg_Product    Egg_size
# 0     899  Happy Egg Heritage Breed Blue & Brown Free Ran...       12 ct
# 1     699  Nellie's Free Range Eggs, Brown, Free Range, L...       12 ct
# 2     699          Horizon Organic Eggs, Fresh, Brown, Large       12 ct
# 3     979  Pete and Gerry’s Organic Eggs Eggs, Organic, F...     12 each
# 4     699  Nellie's Free Range Eggs, Brown, Free Range, L...       12 ct
# 5     399          Nellie's Free Range Free Range Large Eggs        6 ct
# 6     879  Pete and Gerry’s Organic Eggs Eggs, Organic, F...       12 ct
# 7     449            Eggland's Best Grade A Large White Eggs       12 ct
# 8    1099  Vital Farms Organic Pasture Raised Large Grade...       12 ct
# 9     879  Pete and Gerry’s Organic Eggs Eggs, Organic, F...       12 ct
# 10    479          Thomas’ Light Multi-Grain English Muffins   6 x 13 oz
# 11    899      Vital Farms Pasture Raised Large Grade A Eggs       12 ct
# 12    479                      Quaker State Eggs Medium Eggs       21 oz
# 13    469              Eggland's Best Extra Large White Eggs       12 ct
# 14    999                     Bowl & Basket White Large Eggs  30 x 60 oz
# 15    489                      Land O Lakes Large Brown Eggs       12 ct
# 16    849  Pete and Gerry’s Organic Eggs Eggs, Organic, F...       12 ct
# 17    529  Pete and Gerry’s Organic Eggs Eggs, Organic, J...        6 ct
# 18    599                     Bowl & Basket Large White Eggs       18 ct
# 19    419               Bowl & Basket Fresh White Large Eggs       12 ct
# 20    899  Organic Valley Extra Large Brown Free Range Or...       12 ct
# 21    529               Nature's Farms Green Cast Large Eggs        6 ct
# 22    479  Organic Valley Large Brown Free Range Organic ...        6 ct

# %%
df4.to_csv('eggs_at_morton_williams.csv', index=False)

# %% [markdown]
# # Now we will scarpe for White bread at Morton Williams market

# %%
from playwright.async_api import async_playwright

# %%
playwright = await async_playwright().start()

# %%
browser = await playwright.chromium.launch(headless = False)

# %%
browser.new_page()
# Out:
# <coroutine object Browser.new_page at 0x10dd04c50>

# %%
page = await browser.new_page()

# %%
await page.goto("https://www.instacart.com/store/morton-williams-supermarket/search/white%20bread")
# Out:
# <Response url='https://www.instacart.com/store/morton-williams-supermarket/search/white%20bread' request=<Request url='https://www.instacart.com/store/morton-williams-supermarket/search/white%20bread' method='GET'>>

# %%
import pandas as pd

async def scrape_and_merge():
    prices = []
    White_bread_product = []
    bread_size = []

    for i in range(0, 24):
        try:
            price = await page.locator("div.css-1abd9id-ItemBCardDetailsSection div.css-k008qs div.css-lkyxb9-PriceIa").nth(i).inner_text()
            prices.append(price)
        except:
            continue
    df = pd.DataFrame(prices, columns=['prices'])

    for i in range(0, 24):
        try:
            name = await page.locator("h3.css-1w4764r").nth(i).inner_text()
            White_bread_product.append(name)
        except:
            continue
    df2 = pd.DataFrame(White_bread_product, columns=['white_bread_Product'])

    for i in range(0, 24):
        try:
            size = await page.locator("div.css-1301wpr-Size").nth(i).inner_text()
            bread_size.append(size)
        except:
            continue
    df3 = pd.DataFrame(bread_size, columns=['Bread_size'])
    
    df4 = df.merge(df2, left_index=True, right_index=True).merge(df3, left_index=True, right_index=True)

    return df4

df4 = await scrape_and_merge()

df4
# Out:
#    prices                                white_bread_Product Bread_size
# 0     349                       Sara Lee Classic White Bread      20 oz
# 1     369                              Sara Lee Butter Bread      20 oz
# 2     699  Dave's Killer Bread White Bread Done Right, Ar...      24 oz
# 3     469              Arnold Brick Oven Premium White Bread      20 oz
# 4     469                         Arnold Country White Bread      24 oz
# 5     449       Pepperidge Farm Farmhouse Hearty White Bread      24 oz
# 6     299       Pepperidge Farm Italian White Seedless Bread      20 oz
# 7     349                       Sara Lee Classic White Bread      20 oz
# 8     449             Pepperidge Farm Farmhouse Butter Bread      22 oz
# 9     469                 Thomas’ Toast-R-Cakes Corn Muffins   6 x 7 oz
# 10    479                   Thomas’ Original English Muffins      12 oz
# 11    369                         Sara Lee Honey Wheat Bread      20 oz
# 12    269                             Bimbo Soft White Bread      20 oz
# 13    369                              Sara Lee Butter Bread      20 oz
# 14    369                         Sara Lee Honey Wheat Bread      20 oz
# 15    499             Pepperidge Farm Farmhouse Potato Bread      22 oz
# 16    399        Sara Lee Artesano Golden Wheat Bakery Bread      20 oz
# 17    399                 Pepperidge Farm® White White Bread      16 oz
# 18    369                    Sara Lee 100% Whole Wheat Bread      20 oz
# 19    369                    Sara Lee 100% Whole Wheat Bread      20 oz
# 20    469              Arnold Country 100% Whole Wheat Bread      24 oz
# 21    399        Sara Lee Artesano Golden Wheat Bakery Bread      20 oz
# 22    449   Pepperidge Farm Farmhouse 100% Whole Wheat Bread      24 oz
# 23    449    Stroehmann Dutch Country 100% Whole Wheat Bread      24 oz

# %%
df4.to_csv('white_bread_at_morton_williams.csv', index=False)

# %% [markdown]
# # Now we will scrape for Whole Milk at Morton Williams Market

# %%
from playwright.async_api import async_playwright

# %%
playwright = await async_playwright().start()

# %%
browser = await playwright.chromium.launch(headless = False)

# %%
browser.new_page()
# Out:
# <coroutine object Browser.new_page at 0x1052892a0>

# %%
page = await browser.new_page()

# %%
await page.goto("https://www.instacart.com/store/morton-williams-supermarket/search/whole%20milk")
# Out:
# <Response url='https://www.instacart.com/store/morton-williams-supermarket/search/whole%20milk' request=<Request url='https://www.instacart.com/store/morton-williams-supermarket/search/whole%20milk' method='GET'>>

# %%
import pandas as pd

async def scrape_and_merge():
    prices = []
    Whole_milk_product = []
    milk_size = []

    for i in range(0, 24):
        try:
            price = await page.locator("div.css-1abd9id-ItemBCardDetailsSection div.css-k008qs div.css-lkyxb9-PriceIa").nth(i).inner_text()
            prices.append(price)
        except:
            continue
    df = pd.DataFrame(prices, columns=['prices'])

    for i in range(0, 24):
        try:
            name = await page.locator("h3.css-1w4764r").nth(i).inner_text()
            Whole_milk_product.append(name)
        except:
            continue
    df2 = pd.DataFrame(Whole_milk_product, columns=['whole_milk_Product'])

    for i in range(0, 24):
        try:
            size = await page.locator("div.css-1301wpr-Size").nth(i).inner_text()
            milk_size.append(size)
        except:
            continue
    df3 = pd.DataFrame(milk_size, columns=['Milk_size'])
    
    df4 = df.merge(df2, left_index=True, right_index=True).merge(df3, left_index=True, right_index=True)

    return df4

df4 = await scrape_and_merge()

df4
# Out:
#    prices                                 whole_milk_Product Milk_size
# 0    $849                          Organic Valley Whole Milk     64 oz
# 1   $1299  Organic Valley Milk Whole Vitamin D Organic Ga...    128 oz
# 2    $999                         Horizon Organic Whole Milk     1 gal
# 3    $699          Horizon Organic Whole High Vitamin D Milk  64 fl oz
# 4    $479                          Organic Valley Whole Milk  32 fl oz
# 5    $399                       Farmland Whole Milk, Organic   1.5 gal
# 6    $699                      Stonyfield Organic Whole Milk   0.5 gal
# 7    $849                          Organic Valley Whole Milk     64 oz
# 8    $699      Horizon Organic 1% Lowfat High Vitamin D Milk  64 fl oz
# 9    $849                             Organic Valley 2% Milk  64 fl oz
# 10   $849  Organic Valley Ultra Pasteurized Lowfat Organi...  64 fl oz
# 11   $899       Organic Valley Ultra Pasteurized 0% Fat Milk  64 fl oz
# 12   $799  Horizon Organic DHA Omega-3 Vitamin D Organic ...  64 fl oz
# 13   $499                           Farmland 100% Cow's Milk      1 ct
# 14   $189        Farmland Fresh Dairies 100% Real Cow's Milk      1 ct
# 15   $699           Horizon Organic Reduced Fat Organic Milk  64 fl oz
# 16   $599                                a2 Milk Milk, Whole  59 fl oz
# 17   $299        Farmland Fresh Dairies 100% Real Cow's Milk    0.5 ct
# 18   $479                 Organic Valley 2% Reduced Fat Milk     32 oz
# 19   $649    fairlife Whole Ultrafiltered Milk, Lactose Free  52 fl oz
# 20   $599                                 Lactaid Whole Milk   0.5 gal
# 21   $269  Nestlé NESQUIK Chocolate Lowfat Milk Ready to ...  14 fl oz
# 22   $499      Family A2 Farmstead 100% Grass Fed Whole Milk     32 ct
# 23   $499                       Farmland 2% Reduced Fat Milk      1 ct

# %%
df4.to_csv('whole_milk_at_morton_williams.csv', index=False)
