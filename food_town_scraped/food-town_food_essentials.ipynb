# %% [markdown]
# # In this notebook, I will scrape for Food Town Market of Morningside Heights which is on 1316 Amsterdam Avenue near Columbia University for the essential food items on the instacart website.

# %% [markdown]
# # Food-town Market for eggs:

# %%
from playwright.async_api import async_playwright

# %%
playwright = await async_playwright().start()

# %%
browser = await playwright.chromium.launch(headless = False)

# %%
browser.new_page()
# Out:
# <coroutine object Browser.new_page at 0x12c50f5c0>

# %%
page = await browser.new_page()

# %%
await page.goto("https://www.instacart.com/store/foodtown/search/eggs")
# Out:
# <Response url='https://www.instacart.com/store/foodtown/search/eggs' request=<Request url='https://www.instacart.com/store/foodtown/search/eggs' method='GET'>>

# %%
import pandas as pd

async def scrape_and_merge():
    prices = []
    egg_product = []
    egg_size = []

    for i in range(0, 24):
        try:
            price = await page.locator("div.css-1abd9id-ItemBCardDetailsSection div.css-k008qs div.css-lkyxb9-PriceIa").nth(i).inner_text()
            prices.append(price)
        except:
            continue
    df = pd.DataFrame(prices, columns=['prices'])

    for i in range(0, 24):
        try:
            name = await page.locator("h3.css-1w4764r").nth(i).inner_text()
            egg_product.append(name)
        except:
            continue
    df2 = pd.DataFrame(egg_product, columns=['Egg_Product'])

    for i in range(0, 24):
        try:
            size = await page.locator("div.css-1301wpr-Size").nth(i).inner_text()
            egg_size.append(size)
        except:
            continue
    df3 = pd.DataFrame(egg_size, columns=['Egg_size'])
    
    df4 = df.merge(df2, left_index=True, right_index=True).merge(df3, left_index=True, right_index=True)

    return df4

df4 = await scrape_and_merge()

df4
# Out:
#    prices                                        Egg_Product   Egg_size
# 0    $579                           JUST Egg plant-based egg   12 fl oz
# 1    $869  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12 ct
# 2    $679                Foodtown Large Grade AAA White Eggs      12 ct
# 3    $889              Eggland's Best Extra Large White Eggs      18 ct
# 4    $959  Eggland's Best Organic Cage Free Grade A Brown...      12 ct
# 5    $599            Eggland's Best Grade A Large White Eggs      12 ct
# 6    $869  Nellie's Free Range Eggs, Brown, Free Range, L...      12 ct
# 7    $869  Pete and Gerry’s Organic Eggs Eggs, Organic, F...      12 ct
# 8    $978      Vital Farms Pasture Raised Large Grade A Eggs      12 ct
# 9    $609          Thomas’ Light Multi-Grain English Muffins  6 x 13 oz
# 10   $529  Country Crock Plant Butter with Olive Oil, Dai...    10.5 oz
# 11   $689  Country Crock Plant Butter with Avocado Oil, D...     4 each
# 12  $1149  Vital Farms Organic Pasture Raised Large Grade...      12 ct
# 13   $669                Hillandale Farms Jumbo Grade A Eggs      12 ct
# 14   $499  Pete and Gerry’s Organic Eggs Eggs, Organic, F...       6 ct
# 15   $749  Green Way Markets Large Brown Organic Free-Ran...      24 oz
# 16   $579                   Green Way Markets Cage Free Eggs      24 ct
# 17   $789     Utopihen Farms Pasture Raised Large Brown Eggs      12 ct
# 18   $609              Land O Lakes Eggs, Brown, Extra Large      12 ct
# 19   $919  The Farmer's Hen Organic Free Range Large Brow...      12 ct
# 20   $919  The Farmer's Hen Organic Pasture Raised Large ...      12 ct
# 21   $669         Land O Lakes Eggs, Brown, Cage Free, Large    12 each
# 22   $579         Green Way Markets Omega 3 Large Brown Eggs      12 ct
# 23  $1149     The Farmer's Hen Organic Free Range Large Eggs      18 ct

# %%
df4.to_csv('eggs_at_food-town.csv', index=False)

# %% [markdown]
# # Now we will scarpe for bread at Food-Town market

# %%
from playwright.async_api import async_playwright

# %%
playwright = await async_playwright().start()

# %%
browser = await playwright.chromium.launch(headless = False)

# %%
browser.new_page()
# Out:
# <coroutine object Browser.new_page at 0x129e1db00>

# %%
page = await browser.new_page()

# %%
await page.goto("https://www.instacart.com/store/foodtown/search/white%20bread")
# Out:
# <Response url='https://www.instacart.com/store/foodtown/search/white%20bread' request=<Request url='https://www.instacart.com/store/foodtown/search/white%20bread' method='GET'>>

# %%
import pandas as pd

async def scrape_and_merge():
    prices = []
    White_bread_product = []
    bread_size = []

    for i in range(0, 24):
        try:
            price = await page.locator("div.css-1abd9id-ItemBCardDetailsSection div.css-k008qs div.css-lkyxb9-PriceIa").nth(i).inner_text()
            prices.append(price)
        except:
            continue
    df = pd.DataFrame(prices, columns=['prices'])

    for i in range(0, 24):
        try:
            name = await page.locator("h3.css-1w4764r").nth(i).inner_text()
            White_bread_product.append(name)
        except:
            continue
    df2 = pd.DataFrame(White_bread_product, columns=['white_bread_Product'])

    for i in range(0, 24):
        try:
            size = await page.locator("div.css-1301wpr-Size").nth(i).inner_text()
            bread_size.append(size)
        except:
            continue
    df3 = pd.DataFrame(bread_size, columns=['Bread_size'])
    
    df4 = df.merge(df2, left_index=True, right_index=True).merge(df3, left_index=True, right_index=True)

    return df4

df4 = await scrape_and_merge()

df4
# Out:
#    prices                                white_bread_Product Bread_size
# 0    $499  Nature's Own Perfectly Crafted White Bread, Th...      22 oz
# 1    $499  Nature's Own Perfectly Crafted Thick Sliced Br...      22 oz
# 2    $499  Nature's Own Perfectly Crafted White Bread, Th...      22 oz
# 3    $409  Wonder Bread Bread Classic White Sandwich Brea...      20 oz
# 4    $609  Dave's Killer Bread White Bread Done Right, Ar...      24 oz
# 5    $388              Arnold Brick Oven Premium White Bread      20 oz
# 6    $459                         Arnold Country White Bread      24 oz
# 7    $499       Pepperidge Farm Italian White Seedless Bread      20 oz
# 8    $609  Nature's Own Honey Wheat, Honey Wheat Sandwich...      20 oz
# 9    $639       Nature's Own Bread, Multigrain, Thick Sliced      22 oz
# 10   $869                              Sara Lee Butter Bread      20 oz
# 11   $359                 Thomas’ Toast-R-Cakes Corn Muffins   6 x 7 oz
# 12   $459        The Rustik Oven Artisan Pane Italiano Bread      16 oz
# 13   $409                                  Arnold Keto Bread      20 oz
# 14   $609                             Bimbo Soft White Bread      20 oz
# 15   $409                              Sara Lee Butter Bread      20 oz
# 16   $639                       Toufayan Pita, Classic White     6 each

# %% [markdown]
# # Now we will scrape for Whole Milk at Morton Williams Market

# %%
from playwright.async_api import async_playwright

# %%
playwright = await async_playwright().start()

# %%
browser = await playwright.chromium.launch(headless = False)

# %%
browser.new_page()
# Out:
# <coroutine object Browser.new_page at 0x129f0ec90>

# %%
page = await browser.new_page()

# %%
await page.goto("https://www.instacart.com/store/morton-williams-supermarket/search/whole%20milk")
# Out:
# <Response url='https://www.instacart.com/store/morton-williams-supermarket/search/whole%20milk' request=<Request url='https://www.instacart.com/store/morton-williams-supermarket/search/whole%20milk' method='GET'>>

# %%
import pandas as pd

async def scrape_and_merge():
    prices = []
    Whole_milk_product = []
    milk_size = []

    for i in range(0, 24):
        try:
            price = await page.locator("div.css-1abd9id-ItemBCardDetailsSection div.css-k008qs div.css-lkyxb9-PriceIa").nth(i).inner_text()
            prices.append(price)
        except:
            continue
    df = pd.DataFrame(prices, columns=['prices'])

    for i in range(0, 24):
        try:
            name = await page.locator("h3.css-1w4764r").nth(i).inner_text()
            Whole_milk_product.append(name)
        except:
            continue
    df2 = pd.DataFrame(Whole_milk_product, columns=['whole_milk_Product'])

    for i in range(0, 24):
        try:
            size = await page.locator("div.css-1301wpr-Size").nth(i).inner_text()
            milk_size.append(size)
        except:
            continue
    df3 = pd.DataFrame(milk_size, columns=['Milk_size'])
    
    df4 = df.merge(df2, left_index=True, right_index=True).merge(df3, left_index=True, right_index=True)

    return df4

df4 = await scrape_and_merge()

df4
# Out:
#    prices                                 whole_milk_Product Milk_size
# 0    $849                          Organic Valley Whole Milk     64 oz
# 1    $849                             Organic Valley 2% Milk  64 fl oz
# 2    $479                          Organic Valley Whole Milk  32 fl oz
# 3    $399                       Farmland Whole Milk, Organic   1.5 gal
# 4    $849                          Organic Valley Whole Milk     64 oz
# 5    $799  Horizon Organic DHA Omega-3 Vitamin D Organic ...  64 fl oz
# 6    $189        Farmland Fresh Dairies 100% Real Cow's Milk      1 ct
# 7    $499                           Farmland 100% Cow's Milk      1 ct
# 8    $699           Horizon Organic Reduced Fat Organic Milk  64 fl oz
# 9    $849  Organic Valley Ultra Pasteurized Lowfat Organi...  64 fl oz
# 10   $899       Organic Valley Ultra Pasteurized 0% Fat Milk  64 fl oz
# 11   $599                                 Lactaid Whole Milk   0.5 gal
# 12   $499      Family A2 Farmstead 100% Grass Fed Whole Milk     32 ct
# 13   $299        Farmland Fresh Dairies 100% Real Cow's Milk    0.5 ct
# 14   $479                 Organic Valley 2% Reduced Fat Milk     32 oz
# 15   $499                       Farmland 2% Reduced Fat Milk      1 ct
# 16   $849                             Organic Valley 2% Milk  64 fl oz
# 17   $899       Organic Valley Ultra Pasteurized 0% Fat Milk  64 fl oz
# 18   $699      Horizon Organic 1% Lowfat High Vitamin D Milk  64 fl oz
# 19   $599                                      Oatly Oatmilk  64 fl oz
# 20   $269  Nestlé NESQUIK Chocolate Lowfat Milk Ready to ...  14 fl oz
# 21   $269  Nestlé NESQUIK Strawberry Flavored Lowfat Milk...  14 fl oz
# 22   $479  Organic Valley Ultra Pasteurized Lowfat Organi...     32 oz
# 23   $299         Farmland Fresh Dairies 2% Reduced Fat Milk    0.5 ct

# %%
df4.to_csv('whole_milk_at_food-town.csv', index=False)
