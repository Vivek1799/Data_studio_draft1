# %% [markdown]
# # In this notebook, I will scrape for C-Town Market which is on 560 W 125th St near Columbia University for the essential food items on the instacart website.

# %% [markdown]
# # C-Town Market for eggs:

# %%
from playwright.async_api import async_playwright

# %%
playwright = await async_playwright().start()

# %%
browser = await playwright.chromium.launch(headless = False)

# %%
browser.new_page()
# Out:
# <coroutine object Browser.new_page at 0x11ce37cb0>

# %%
page = await browser.new_page()

# %%
await page.goto("https://www.instacart.com/store/ctown-supermarkets/search/eggs")
# Out:
# <Response url='https://www.instacart.com/store/ctown-supermarkets/search/eggs' request=<Request url='https://www.instacart.com/store/ctown-supermarkets/search/eggs' method='GET'>>

# %%
import pandas as pd

async def scrape_and_merge():
    prices = []
    egg_product = []
    egg_size = []

    for i in range(0, 24):
        try:
            price = await page.locator("div.css-1abd9id-ItemBCardDetailsSection div.css-k008qs div.css-lkyxb9-PriceIa").nth(i).inner_text()
            prices.append(price)
        except:
            continue
    df = pd.DataFrame(prices, columns=['prices'])

    for i in range(0, 24):
        try:
            name = await page.locator("h3.css-1w4764r").nth(i).inner_text()
            egg_product.append(name)
        except:
            continue
    df2 = pd.DataFrame(egg_product, columns=['Egg_Product'])

    for i in range(0, 24):
        try:
            size = await page.locator("div.css-1301wpr-Size").nth(i).inner_text()
            egg_size.append(size)
        except:
            continue
    df3 = pd.DataFrame(egg_size, columns=['Egg_size'])
    
    df4 = df.merge(df2, left_index=True, right_index=True).merge(df3, left_index=True, right_index=True)

    return df4

df4 = await scrape_and_merge()

df4
# Out:
#    prices                                        Egg_Product  Egg_size
# 0    $549                           JUST Egg plant-based egg  12 fl oz
# 1    $499            Eggland's Best Grade A Large White Eggs     12 ct
# 2    $739                    Eggland's Best Large White Eggs     18 ct
# 3    $489                      Land O Lakes Large Brown Eggs     12 ct
# 4    $749              Eggland's Best Extra Large White Eggs     18 ct
# 5    $279                                  Medium White Eggs     12 ct
# 6    $389            Eggland's Best Grade A Large White Eggs     12 ct
# 7    $589  Eggland's Best Cage Free Grade A Large Brown Eggs     12 ct
# 8    $469       Country Crock Vegetable Oil Spread, Original     15 oz
# 9    $919          Horizon Organic Eggs, Fresh, Brown, Large     12 ct
# 10   $659           Aldefer Organic Large Brown Grade A Eggs     12 ct
# 11   $719  Nature's Yoke Free-Range Organic Large Brown Eggs     12 ct
# 12   $439         Sauders Grade A Large Brown Cage-Free Eggs    1 each
# 13   $329    The Farmer's Hen Organic Free Range Medium Eggs     12 ct
# 14   $439  Organic Valley Large Brown Free Range Organic ...      6 ct
# 15   $659                          Pine Belt Large White Egg     24 oz
# 16   $879  Nature's Yoke Organic Free-Range Extra Large B...     12 ct
# 17   $389                          Carr's Grade A Jumbo Eggs     14 oz
# 18   $549           Pine Belt Eggs Grade AA Extra Large Eggs     12 ct
# 19   $719  The Farmer's Hen Classic Free Range Large Brow...     18 ct
# 20   $719  The Farmer's Hen Organic Free Range Large Brow...     12 ct
# 21   $479  The Farmer's Hen Classic Free Range Large Brow...     12 ct
# 22   $549                Hillandale Farms Jumbo Grade A Eggs     12 ct
# 23   $579           Land O Lakes Eggs, Brown, Grade A, Jumbo     12 ct

# %%
df4.to_csv('eggs_at_Ctown.csv', index=False)

# %% [markdown]
# # Now we will scarpe for bread at C-Town market

# %%
from playwright.async_api import async_playwright

# %%
playwright = await async_playwright().start()

# %%
browser = await playwright.chromium.launch(headless = False)

# %%
browser.new_page()
# Out:
# <coroutine object Browser.new_page at 0x10450d640>

# %%
page = await browser.new_page()

# %%
await page.goto("https://www.instacart.com/store/ctown-supermarkets/search/white%20bread")
# Out:
# <Response url='https://www.instacart.com/store/ctown-supermarkets/search/white%20bread' request=<Request url='https://www.instacart.com/store/ctown-supermarkets/search/white%20bread' method='GET'>>

# %%
import pandas as pd

async def scrape_and_merge():
    prices = []
    White_bread_product = []
    bread_size = []

    for i in range(0, 24):
        try:
            price = await page.locator("div.css-1abd9id-ItemBCardDetailsSection div.css-k008qs div.css-lkyxb9-PriceIa").nth(i).inner_text()
            prices.append(price)
        except:
            continue
    df = pd.DataFrame(prices, columns=['prices'])

    for i in range(0, 24):
        try:
            name = await page.locator("h3.css-1w4764r").nth(i).inner_text()
            White_bread_product.append(name)
        except:
            continue
    df2 = pd.DataFrame(White_bread_product, columns=['white_bread_Product'])

    for i in range(0, 24):
        try:
            size = await page.locator("div.css-1301wpr-Size").nth(i).inner_text()
            bread_size.append(size)
        except:
            continue
    df3 = pd.DataFrame(bread_size, columns=['Bread_size'])
    
    df4 = df.merge(df2, left_index=True, right_index=True).merge(df3, left_index=True, right_index=True)

    return df4

df4 = await scrape_and_merge()

df4
# Out:
# ---------------------------------------------------------------------------
# GeneratorExit                             Traceback (most recent call last)
# GeneratorExit:
# ---------------------------------------------------------------------------
# GeneratorExit                             Traceback (most recent call last)
# GeneratorExit:
#    prices                                white_bread_Product Bread_size
# 0    $329                              Sara Lee Butter Bread      20 oz
# 1    $439         Sara Lee White made with Whole Wheat Bread      20 oz
# 2    $439                    Sara Lee 100% Whole Wheat Bread      20 oz
# 3    $409  Nature's Own Perfectly Crafted White Bread, Th...      22 oz
# 4    $689  Dave's Killer Bread White Bread Done Right, Ar...      24 oz
# 5    $439       Pepperidge Farm Farmhouse Hearty White Bread      24 oz
# 6    $329  Nature's Own Butterbread, Sliced White Bread, ...      20 oz
# 7    $319  Pepperidge Farm® Italian Italian with Sesame S...      20 oz
# 8    $329                     Sara Lee Artesano Bakery Bread      20 oz
# 9    $329                              Sara Lee Butter Bread      20 oz
# 10   $439         Sara Lee White made with Whole Wheat Bread      20 oz
# 11   $409  Nature's Own Perfectly Crafted White Bread, Th...      22 oz
# 12   $689  Dave's Killer Bread White Bread Done Right, Ar...      24 oz
# 13   $329  Nature's Own Butterbread, Sliced White Bread, ...      20 oz
# 14   $439       Pepperidge Farm Farmhouse Hearty White Bread      24 oz
# 15   $409  Nature's Own Perfectly Crafted Thick Sliced Br...      22 oz
# 16   $439  Pepperidge Farm Farmhouse Whole Grain White Bread      24 oz
# 17   $319  Pepperidge Farm® Italian Italian with Sesame S...      20 oz
# 18   $439                    Sara Lee 100% Whole Wheat Bread      20 oz
# 19   $499          Thomas’ Light Multi-Grain English Muffins  6 x 13 oz
# 20   $499         Arnold Whole Grains 100% Whole Wheat Bread      24 oz
# 21   $439         Sara Lee White made with Whole Wheat Bread      20 oz
# 22   $689  Dave's Killer Bread 21 Whole Grains and Seeds ...      27 oz
# 23   $439             Pepperidge Farm Farmhouse Butter Bread      22 oz

# %%
df4.to_csv('white_bread_at_Ctown.csv', index=False)

# %% [markdown]
# # Now we will scrape for Whole Milk at C-Town Market

# %%
from playwright.async_api import async_playwright

# %%
playwright = await async_playwright().start()

# %%
browser = await playwright.chromium.launch(headless = False)

# %%
browser.new_page()
# Out:
# <coroutine object Browser.new_page at 0x1039a0d60>

# %%
page = await browser.new_page()

# %%
await page.goto("https://www.instacart.com/store/ctown-supermarkets/search/whole%20milk")
# Out:
# <Response url='https://www.instacart.com/store/ctown-supermarkets/search/whole%20milk' request=<Request url='https://www.instacart.com/store/ctown-supermarkets/search/whole%20milk' method='GET'>>

# %%
import pandas as pd

async def scrape_and_merge():
    prices = []
    Whole_milk_product = []
    milk_size = []

    for i in range(0, 24):
        try:
            price = await page.locator("div.css-1abd9id-ItemBCardDetailsSection div.css-k008qs div.css-lkyxb9-PriceIa").nth(i).inner_text()
            prices.append(price)
        except:
            continue
    df = pd.DataFrame(prices, columns=['prices'])

    for i in range(0, 24):
        try:
            name = await page.locator("h3.css-1w4764r").nth(i).inner_text()
            Whole_milk_product.append(name)
        except:
            continue
    df2 = pd.DataFrame(Whole_milk_product, columns=['whole_milk_Product'])

    for i in range(0, 24):
        try:
            size = await page.locator("div.css-1301wpr-Size").nth(i).inner_text()
            milk_size.append(size)
        except:
            continue
    df3 = pd.DataFrame(milk_size, columns=['Milk_size'])
    
    df4 = df.merge(df2, left_index=True, right_index=True).merge(df3, left_index=True, right_index=True)

    return df4

df4 = await scrape_and_merge()

df4
# Out:
#    prices                                 whole_milk_Product  Milk_size
# 0    $829                          Organic Valley Whole Milk      64 oz
# 1    $829                             Organic Valley 2% Milk   64 fl oz
# 2    $189                           Cream-O-Land Milk, Whole       1 qt
# 3    $529                           Cream-O-Land Milk, Whole      1 gal
# 4    $329                           Cream-O-Land Milk, Whole    0.5 gal
# 5    $769          Horizon Organic Whole High Vitamin D Milk   64 fl oz
# 6    $829                          Organic Valley Whole Milk      64 oz
# 7   $1489                         Horizon Organic Whole Milk      1 gal
# 8    $829  Horizon Organic DHA Omega-3 Vitamin D Organic ...   64 fl oz
# 9    $829  Organic Valley Ultra Pasteurized Lowfat Organi...   64 fl oz
# 10   $769       Organic Valley Ultra Pasteurized 0% Fat Milk   64 fl oz
# 11   $609                                      Oatly Oatmilk   64 fl oz
# 12   $849                      Stonyfield Organic Whole Milk    0.5 gal
# 13   $939        Organic Valley Grassmilk Organic Whole Milk      64 oz
# 14   $859                Horizon Organic Whole Grassfed Milk    0.5 gal
# 15   $739    fairlife Whole Ultrafiltered Milk, Lactose Free   52 fl oz
# 16   $939                                 Lactaid Whole Milk   96 fl oz
# 17   $659                                 Lactaid Whole Milk    0.5 gal
# 18  $1489  Horizon Organic 2% Reduced Fat High Vitamin D ...  128 fl oz
# 19   $659                                 Lactaid Whole Milk    0.5 gal
# 20   $939                                 Lactaid Whole Milk   96 fl oz
# 21   $529           Planet Oat Extra Creamy Original Oatmilk   52 fl oz
# 22   $829  Horizon Organic Lactose-Free Vitamin D Organic...   64 fl oz
# 23  $1159  DairyPure Half & Half Ultra-Pasteurized Half G...   64 fl oz

# %%
df4.to_csv('whole_milk_at_ctown.csv', index=False)
